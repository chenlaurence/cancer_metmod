# %%
import cobra
import cobra.test
import json
import os
from IPython.display import HTML
import numpy as np
# Out:
# cobra/io/__init__.py:17 UserWarning: cobra.io.sbml requires libsbml

# %%
# Growth is 0 (or essentially 0)

model = cobra.io.load_matlab_model('/Users/LAURENCE/Desktop/Senior Design/RECON1', 'RECON1')
solution = model.optimize()
print solution.f
# Out:
# -1.18308253889e-11

# %%
# To illustrate that the indexes 1188:1591 of the reaction
# covers all the EX reactions

print model.reactions[1187]
print model.reactions[1188]
print model.reactions[1591]
print model.reactions[1592]
# Out:
# ETOHtx
# EX_10fthf6glu_e
# EX_yvite_e
# F1PGT

# %%
# Checking to see which reactions have lower bounds < 0

lessthan_EX = model.reactions[1188:1591]
lessthan = []
for a in range(len(lessthan_EX)):
    if lessthan_EX[a].lower_bound < 0:
        lessthan.append(lessthan_EX[a].id)
lessthan
# Out:
# ['EX_10fthf6glu_e',
#  'EX_10fthf7glu_e',
#  'EX_10fthf_e',
#  'EX_11_cis_retfa_e',
#  'EX_13_cis_retnglc_e',
#  'EX_1glyc_hs_e',
#  'EX_1mncam_e',
#  'EX_2425dhvitd2_e',
#  'EX_2425dhvitd3_e',
#  'EX_24nph_e',
#  'EX_25hvitd2_e',
#  'EX_25hvitd3_e',
#  'EX_2hb_e',
#  'EX_2mcit_e',
#  'EX_34dhoxpeg_e',
#  'EX_34dhphe_e',
#  'EX_35cgmp_e',
#  'EX_3aib__D_e',
#  'EX_3aib_e',
#  'EX_3mlda_e',
#  'EX_4abut_e',
#  'EX_4hdebrisoquine_e',
#  'EX_4hphac_e',
#  'EX_4mtolbutamide_e',
#  'EX_4nph_e',
#  'EX_4nphsf_e',
#  'EX_4pyrdx_e',
#  'EX_5adtststerone_e',
#  'EX_5adtststeroneglc_e',
#  'EX_5adtststerones_e',
#  'EX_5dhf_e',
#  'EX_5fthf_e',
#  'EX_5homeprazole_e',
#  'EX_5htrp_e',
#  'EX_5mthf_e',
#  'EX_5thf_e',
#  'EX_6dhf_e',
#  'EX_6htststerone_e',
#  'EX_6thf_e',
#  'EX_7dhf_e',
#  'EX_7thf_e',
#  'EX_9_cis_retfa_e',
#  'EX_clpnd_e',
#  'EX_Lcystin_e',
#  'EX_Rtotal2_e',
#  'EX_Rtotal3_e',
#  'EX_Rtotal_e',
#  'EX_Tyr_ggn_e',
#  'EX_abt_e',
#  'EX_ac_e',
#  'EX_acac_e',
# ...

# %%
# it appears that all exchange reactions have lb < 0

print len(lessthan_EX)
print len(lessthan)
# Out:
# 403
# 403

# %%
# to confirm that all exchange rxns indeed have lb < 0

for a in range(len(lessthan_EX)):
    print lessthan_EX[a].lower_bound
# Out:
# -999999.0
# -999999.0
# -999999.0
# -999999.0
# -999999.0
# -999999.0
# -999999.0
# -999999.0
# -999999.0
# -999999.0
# -999999.0
# -999999.0
# -999999.0
# -999999.0
# -999999.0
# -999999.0
# -999999.0
# -999999.0
# -999999.0
# -999999.0
# -999999.0
# -999999.0
# -999999.0
# -999999.0
# -999999.0
# -999999.0
# -999999.0
# -999999.0
# -999999.0
# -999999.0
# -999999.0
# -999999.0
# -999999.0
# -999999.0
# -999999.0
# -999999.0
# -999999.0
# -999999.0
# -999999.0
# -999999.0
# -999999.0
# -999999.0
# -999999.0
# -999999.0
# -999999.0
# -999999.0
# -999999.0
# -999999.0
# -999999.0
# -999999.0
# -999999.0
# -999999.0
# -999999.0
# -999999.0
# -999999.0
# -999999.0
# -999999.0
# -999999.0
# -999999.0
# -999999.0
# -999999.0
# -999999.0
# -999999.0
# -999999.0
# -999999.0
# -999999.0
# -999999.0
# -999999.0
# -999999.0
# -999999.0
# -999999.0
# -999999.0
# -999999.0
# -999999.0
# -999999.0
# -999999.0
# -999999.0
# -999999.0
# -999999.0
# -999999.0
# -999999.0
# -999999.0
# -999999.0
# ...
