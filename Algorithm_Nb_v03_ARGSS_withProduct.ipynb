# %% [markdown]
# # What is the gene knockout you are interested in studying?

# %%
# This version of the algorithm uses FBA and not pFBA
# fluxes below 10^-5 are rounded to 0 for ranking purposes

# %%
gene_name = raw_input('Enter the name of the gene you are interested in studying as named in model RECON1:   ')
# Out:
# Enter the name of the gene you are interested in studying as named in model RECON1:   ARGSS

# %%
from cobra import Reaction
import escher
import escher.urls
import cobra
import cobra.test
import json
import os
import string
from IPython.display import HTML
from cobra import Model, Reaction, Metabolite
from cobra.flux_analysis.parsimonious import optimize_minimal_flux
model = cobra.io.load_matlab_model('/Users/LAURENCE/Desktop/Senior Design/RECON1', 'RECON1')
# Out:
# cobra/io/__init__.py:17 UserWarning: cobra.io.sbml requires libsbml
# cobra/io/mat.py:136 FutureWarning: elementwise == comparison failed and returning scalar instead; this will raise an error or perform elementwise comparison in the future.

# %% [markdown]
# ## Run all of this to set up RECON1

# %%
#creat ethanalamine demand
#metabolite is etha_c

DM_etha_c = Reaction('DM_etha_c')
DM_etha_c.name = DM_etha_c

etha_c = model.metabolites.get_by_id('etha_c')

DM_etha_c.add_metabolites({etha_c: -1})
model.add_reaction(DM_etha_c)

#create a transporter for this

Tyr_ggnt = Reaction('Tyr_ggnt')
Tyr_ggnt.name = Tyr_ggnt

Tyr_ggn_e = model.metabolites.get_by_id('Tyr_ggn_e')
Tyr_ggn_c = model.metabolites.get_by_id('Tyr_ggn_c')

Tyr_ggnt.add_metabolites({Tyr_ggn_e: -1, Tyr_ggn_c: 1})
model.add_reaction(Tyr_ggnt)

DM_etha_c.lower_bound = -1
Tyr_ggnt.lower_bound = -1000

except_EX_names = '''DM_etha_c, EX_peplys_e, EX_Tyr_ggn_e, EX_arg__L_e, EX_asn__L_e, EX_asp__L_e, EX_chol_e, EX_cl_e, EX_glc__D_e, EX_gln__L_e, EX_gly_e, EX_h_e, EX_h2o_e, EX_ile__L_e, EX_k_e, EX_leu__L_e, EX_lys__L_e, EX_na1_e, EX_nh4_e, EX_o2_e, EX_phe__L_e, EX_pi_e, EX_pro__L_e, EX_ser__L_e, EX_thr__L_e, EX_trp__L_e, EX_tyr__L_e, EX_val__L_e'''
except_EX_names_split = except_EX_names.split(', ')
print except_EX_names_split

# Changing all lower bounds to 0 except the given reactions above

for a in model.reactions[1188:1591]:
    a.lower_bound = 0

model.reactions.get_by_id('EX_yvite_e').lower_bound = 0
model.reactions.get_by_id('EX_10fthf5glu_e').lower_bound = 0
    
for b in model.reactions[1188:1591]:
    for c in range(len(except_EX_names_split)):  
        if b.id  == except_EX_names_split[c]:
            b.lower_bound = -1
            
biomass_NCI60 = Reaction('biomass_NCI60')
biomass_NCI60.name = biomass_NCI60

ala_L_c = model.metabolites.get_by_id('ala__L_c')
arg_L_c = model.metabolites.get_by_id('arg__L_c')
asn_L_c = model.metabolites.get_by_id('asn__L_c')
asp_L_c = model.metabolites.get_by_id('asp__L_c')
atp_c = model.metabolites.get_by_id('atp_c')
clpn_hs_c = model.metabolites.get_by_id('clpn_hs_c')
ctp_c = model.metabolites.get_by_id('ctp_c')
dag_hs_c = model.metabolites.get_by_id('dag_hs_c')
datp_c = model.metabolites.get_by_id('datp_c')
dctp_c = model.metabolites.get_by_id('dctp_c')
dgtp_c = model.metabolites.get_by_id('dgtp_c')
dttp_c = model.metabolites.get_by_id('dttp_c')
gln_L_c = model.metabolites.get_by_id('gln__L_c')
glu_L_c = model.metabolites.get_by_id('glu__L_c')
gly_c = model.metabolites.get_by_id('gly_c')
glygn2_c = model.metabolites.get_by_id('glygn2_c')
gtp_c = model.metabolites.get_by_id('gtp_c')
h2o_c = model.metabolites.get_by_id('h2o_c')
hdca_c = model.metabolites.get_by_id('hdca_c')
hdcea_c = model.metabolites.get_by_id('hdcea_c')
ile_L_c = model.metabolites.get_by_id('ile__L_c')
leu_L_c = model.metabolites.get_by_id('leu__L_c')
lpchol_hs_c = model.metabolites.get_by_id('lpchol_hs_c')
lys_L_c = model.metabolites.get_by_id('lys__L_c')
mag_hs_c = model.metabolites.get_by_id('mag_hs_c')
ocdca_c = model.metabolites.get_by_id('ocdca_c')
ocdcea_c = model.metabolites.get_by_id('ocdcea_c')
pa_hs_c = model.metabolites.get_by_id('pa_hs_c')
pail_hs_c = model.metabolites.get_by_id('pail_hs_c')
pchol_hs_c = model.metabolites.get_by_id('pchol_hs_c')
pe_hs_c = model.metabolites.get_by_id('pe_hs_c')
phe_L_c = model.metabolites.get_by_id('phe__L_c')
ps_hs_c = model.metabolites.get_by_id('ps_hs_c')
ser_L_c = model.metabolites.get_by_id('ser__L_c')
sphmyln_hs_c = model.metabolites.get_by_id('sphmyln_hs_c')
thr_L_c = model.metabolites.get_by_id('thr__L_c')
trp_L_c = model.metabolites.get_by_id('trp__L_c')
tyr_L_c = model.metabolites.get_by_id('tyr__L_c')
utp_c = model.metabolites.get_by_id('utp_c')
val_L_c = model.metabolites.get_by_id('val__L_c')
pro_L_m = model.metabolites.get_by_id('pro__L_m')
chsterol_r = model.metabolites.get_by_id('chsterol_r')
xolest_hs_r = model.metabolites.get_by_id('xolest_hs_r')
adp_c = model.metabolites.get_by_id('adp_c')
h_c = model.metabolites.get_by_id('h_c')
pi_c = model.metabolites.get_by_id('pi_c')

#remove ocdca and ocdcea
# added xolest value to cholesterol in biomass and remove xolest

biomass_NCI60.add_metabolites({ala_L_c: -0.587929, arg_L_c: -0.380280, asn_L_c: -0.323313, asp_L_c: -0.261396, 
                               atp_c: -35.033540, clpn_hs_c: -0.000624, ctp_c: -0.033435, dag_hs_c: -0.001032, 
                               datp_c: -0.014557, dctp_c: -0.009770, dgtp_c: -0.009748, dttp_c: -0.014546,
                               gln_L_c: -0.319051, glu_L_c: -0.387401, gly_c: -0.504294, glygn2_c: -0.034479,
                               gtp_c: -0.055967, h2o_c: -35.000000, hdca_c: -0.008293, hdcea_c: -0.003315, 
                               ile_L_c: -0.319813, leu_L_c: -0.548692, lpchol_hs_c: -0.002470, lys_L_c: -0.552717, 
                               mag_hs_c: -0.001456, pa_hs_c: -0.010645,
                               pail_hs_c: -0.005016, pchol_hs_c: -0.022878, pe_hs_c: -0.018211, phe_L_c: -0.170743,
                               ps_hs_c: -0.006808, ser_L_c: -0.385852, sphmyln_hs_c: -0.010215, thr_L_c: -0.378004, 
                               trp_L_c: -0.039847, tyr_L_c: -0.150141, utp_c: -0.063323, val_L_c: -0.385554,
                               pro_L_m: -0.237850, chsterol_r: -0.054102,  adp_c: 35.000000, 
                               h_c: 35.000000, pi_c: 35.000000})

model.add_reaction(biomass_NCI60)
my_objective = model.reactions.get_by_id('biomass_NCI60')
model.change_objective(my_objective)

# Adding DM_atp_c reaction

DM_atp_c = Reaction('DM_atp_c')
DM_atp_c.name = DM_atp_c

atp_c = model.metabolites.get_by_id('atp_c')
adp_c = model.metabolites.get_by_id('adp_c')
h2o_c = model.metabolites.get_by_id('h2o_c')
h_c = model.metabolites.get_by_id('h_c')
pi_c = model.metabolites.get_by_id('pi_c')


DM_atp_c.add_metabolites({atp_c: -1, h2o_c: -1, adp_c: 1, pi_c: 1, h_c: 1})
model.add_reaction(DM_atp_c)

# Setting lower bounds for DM_atp_c as per Dan

#model.reactions.get_by_id('DM_atp_c').lower_bound = 0.9*7.9939

model.reactions.get_by_id('EX_h_e').lower_bound = -1000
model.reactions.get_by_id('EX_o2_e').lower_bound = -1000
model.reactions.get_by_id('EX_fe2_e').lower_bound = -1000
model.reactions.get_by_id('EX_nh4_e').lower_bound = -1000

model.reactions.get_by_id('EX_glc__D_e').lower_bound = -0.4882

# constrained as per calculate fluxes 
model.reactions.get_by_id('biomass_NCI60').lower_bound = 0.0177
model.reactions.get_by_id('biomass_NCI60').upper_bound = 0.0177

model.reactions.get_by_id('EX_pi_e').lower_bound = -1000

# 6/16/16 Changing amino acid uptake constraints
# arg__L__e initially was -0.0022
model.reactions.get_by_id('EX_arg__L_e').lower_bound = -0.0068

model.reactions.get_by_id('EX_asn__L_e').lower_bound = -0.0058
model.reactions.get_by_id('EX_asp__L_e').lower_bound = -0.0081
model.reactions.get_by_id('EX_chol_e').lower_bound = -0.00062386
model.reactions.get_by_id('EX_gln__L_e').lower_bound = -0.1202
model.reactions.get_by_id('EX_gly_e').lower_bound = -0.0019
model.reactions.get_by_id('EX_ile__L_e').lower_bound = -0.0081
model.reactions.get_by_id('EX_leu__L_e').lower_bound = -0.0110
model.reactions.get_by_id('EX_lys__L_e').lower_bound = -0.0111
model.reactions.get_by_id('EX_phe__L_e').lower_bound = -0.0040

model.reactions.get_by_id('EX_pro__L_e').lower_bound = -0.0045

model.reactions.get_by_id('EX_ser__L_e').lower_bound = -0.0167
model.reactions.get_by_id('EX_trp__L_e').lower_bound = -0.0013
model.reactions.get_by_id('EX_tyr__L_e').lower_bound = -0.0068
model.reactions.get_by_id('EX_val__L_e').lower_bound = -0.0079

#6/24/16 lowerbound changes

model.reactions.get_by_id('FTHFLi').lower_bound = 0
model.reactions.get_by_id('FTHFLmi').lower_bound = 0

model.reactions.get_by_id('FUM').lower_bound = 0
model.reactions.get_by_id('FUM').upper_bound = 0

model.reactions.get_by_id('BILGLCURte').lower_bound = 0
model.reactions.get_by_id('BILDGLCURte').lower_bound = 0

h_i = Metabolite('h_i', formula='h', name='h_i', compartment='i')
model.add_metabolites(h_i)


# delete reaction
model.remove_reactions('ATPS4m')

# re-add the reaction while replacing h_c with h_i
ATPS4m = Reaction('ATPS4m')
ATPS4m.name = ATPS4m

adp_m = model.metabolites.get_by_id('adp_m')
h_i = model.metabolites.get_by_id('h_i')
pi_m = model.metabolites.get_by_id('pi_m')
h2o_m = model.metabolites.get_by_id('h2o_m')
h_m = model.metabolites.get_by_id('h_m')
atp_m = model.metabolites.get_by_id('atp_m')

ATPS4m.add_metabolites({adp_m: -1, h_i: -4, pi_m: -1, h2o_m: 1, h_m: 3, atp_m: 1})
model.add_reaction(ATPS4m)

model.remove_reactions('CYOOm3')

CYOOm2 = Reaction('CYOOm2')
CYOOm2.name = CYOOm2

h_m = model.metabolites.get_by_id('h_m')
o2_m = model.metabolites.get_by_id('o2_m')
focytC_m = model.metabolites.get_by_id('focytC_m')
h_i = model.metabolites.get_by_id('h_i')
h2o_m = model.metabolites.get_by_id('h2o_m')
ficytC_m = model.metabolites.get_by_id('ficytC_m')


CYOOm2.add_metabolites({h_m: -8, o2_m: -1, focytC_m: -4, h_i: 4, h2o_m: 2, ficytC_m: 4})
model.add_reaction(CYOOm2)

# delete reaction
model.remove_reactions('NADH2_u10m')

# re-add the reaction while replacing h_c with h_i
NADH2_u10m = Reaction('NADH2_u10m')
NADH2_u10m.name = NADH2_u10m

q10_m = model.metabolites.get_by_id('q10_m')
h_m = model.metabolites.get_by_id('h_m')
nadh_m = model.metabolites.get_by_id('nadh_m')
nad_m = model.metabolites.get_by_id('nad_m')
h_i = model.metabolites.get_by_id('h_i')
q10h2_m = model.metabolites.get_by_id('q10h2_m')



NADH2_u10m.add_metabolites({q10_m: -1, h_m: -5, nadh_m: -1, nad_m: 1, h_i: 4, q10h2_m: 1})
model.add_reaction(NADH2_u10m)

# delete reaction
model.remove_reactions('CYOR_u10m')

# re-add the reaction while replacing h_c with h_i
CYOR_u10m = Reaction('CYOR_u10m')
CYOR_u10m.name = NADH2_u10m

ficytC_m = model.metabolites.get_by_id('ficytC_m')
h_m = model.metabolites.get_by_id('h_m')
q10h2_m = model.metabolites.get_by_id('q10h2_m')
q10_m = model.metabolites.get_by_id('q10_m')
focytC_m = model.metabolites.get_by_id('focytC_m')
h_i = model.metabolites.get_by_id('h_i')


CYOR_u10m.add_metabolites({ficytC_m: -2, h_m: -2, q10h2_m: -1, q10_m: 1, focytC_m: 2, h_i: 4})
model.add_reaction(CYOR_u10m)
# Out:
# ['DM_etha_c', 'EX_peplys_e', 'EX_Tyr_ggn_e', 'EX_arg__L_e', 'EX_asn__L_e', 'EX_asp__L_e', 'EX_chol_e', 'EX_cl_e', 'EX_glc__D_e', 'EX_gln__L_e', 'EX_gly_e', 'EX_h_e', 'EX_h2o_e', 'EX_ile__L_e', 'EX_k_e', 'EX_leu__L_e', 'EX_lys__L_e', 'EX_na1_e', 'EX_nh4_e', 'EX_o2_e', 'EX_phe__L_e', 'EX_pi_e', 'EX_pro__L_e', 'EX_ser__L_e', 'EX_thr__L_e', 'EX_trp__L_e', 'EX_tyr__L_e', 'EX_val__L_e']
# cobra/core/Model.py:306 UserWarning: need to pass in a list

# %% [markdown]
# ## Calculating the normal, healthy demands

# %%
p_solution = cobra.flux_analysis.parsimonious.optimize_minimal_flux(model)

# %%
# constraining the upper and lower bound of the gene of interest to an optimized value

model.reactions.get_by_id(str(gene_name)).upper_bound = p_solution.x_dict[str(gene_name)] + 0.005
model.reactions.get_by_id(str(gene_name)).lower_bound = p_solution.x_dict[str(gene_name)] - 0.005

# %%
'''amp_c = model.metabolites.get_by_id('amp_c')
DM_amp_c = Reaction('DM_amp_c')
DM_amp_c.name = DM_amp_c
DM_amp_c.add_metabolites({amp_c: -1})
model.add_reaction(DM_amp_c)
'''
argsuc_c = model.metabolites.get_by_id('argsuc_c')
DM_argsuc_c = Reaction('DM_argsuc_c')
DM_argsuc_c.name = DM_argsuc_c
DM_argsuc_c.add_metabolites({argsuc_c: -1})
model.add_reaction(DM_argsuc_c)
'''
h_c = model.metabolites.get_by_id('h_c')
DM_h_c = Reaction('DM_h_c')
DM_h_c.name = DM_h_c
DM_h_c.add_metabolites({h_c: -1})
model.add_reaction(DM_h_c)'''

'''ppi_c = model.metabolites.get_by_id('ppi_c')
DM_ppi_c = Reaction('DM_ppi_c')
DM_ppi_c.name = DM_ppi_c
DM_ppi_c.add_metabolites({ppi_c: -1})
model.add_reaction(DM_ppi_c)'''
# Out:
# "ppi_c = model.metabolites.get_by_id('ppi_c')\nDM_ppi_c = Reaction('DM_ppi_c')\nDM_ppi_c.name = DM_ppi_c\nDM_ppi_c.add_metabolites({ppi_c: -1})\nmodel.add_reaction(DM_ppi_c)"

# %%
'''model.reactions.get_by_id('DM_amp_c').upper_bound = p_solution.x_dict[str(gene_name)] + 0.005
model.reactions.get_by_id('DM_amp_c').lower_bound = p_solution.x_dict[str(gene_name)] - 0.005'''

model.reactions.get_by_id('DM_argsuc_c').upper_bound = p_solution.x_dict[str(gene_name)] + 0.005
model.reactions.get_by_id('DM_argsuc_c').lower_bound = p_solution.x_dict[str(gene_name)] - 0.005

'''model.reactions.get_by_id('DM_h_c').upper_bound = p_solution.x_dict[str(gene_name)] + 0.005
model.reactions.get_by_id('DM_h_c').lower_bound = p_solution.x_dict[str(gene_name)] - 0.005

model.reactions.get_by_id('DM_ppi_c').upper_bound = p_solution.x_dict[str(gene_name)] + 0.005
model.reactions.get_by_id('DM_ppi_c').lower_bound = p_solution.x_dict[str(gene_name)] - 0.005'''
# Out:
# "model.reactions.get_by_id('DM_h_c').upper_bound = p_solution.x_dict[str(gene_name)] + 0.005\nmodel.reactions.get_by_id('DM_h_c').lower_bound = p_solution.x_dict[str(gene_name)] - 0.005\n\nmodel.reactions.get_by_id('DM_ppi_c').upper_bound = p_solution.x_dict[str(gene_name)] + 0.005\nmodel.reactions.get_by_id('DM_ppi_c').lower_bound = p_solution.x_dict[str(gene_name)] - 0.005"

# %%
# This creates an array of modified met names

newmet_array = [0] * len(model.metabolites)
met_count = 0
for i in range(len(model.metabolites)):
    newmet_array[met_count] = string.replace(model.metabolites[i].id, " ", "_")
    met_count = met_count + 1

# %%
# creates an empty dict to store DM_rxns as keys and the p_solution.f values
normal_maxmet_dict = {}

for i in range(len(model.metabolites)):
#for i in range(80):

    # this part creates a demand reaction for each metabolite
    temp_DM = 'DM_' + str(newmet_array[i])
    
    # this nested for loop tries to catch if a demand reaction already exists in the model
    for ii in model.reactions:
        if temp_DM == str(ii):
            # this part sets the newly created demand as the objective
            my_objective = model.reactions.get_by_id(str(temp_DM))
            model.change_objective(my_objective)

            # this part runs FBA on the new demand
            p_solution = model.optimize()

            # this stores the demand flux into a dictionary where its demand rxn is the key
            normal_maxmet_dict[str(temp_DM)] = p_solution.f

            # this deletes the demand at the end of each iteration
            model.reactions.get_by_id(str(temp_DM)).delete()
            
    temp_DM = Reaction(str(temp_DM))
    newmet_array[i] = model.metabolites.get_by_id(model.metabolites[i].id)
    temp_DM.add_metabolites({newmet_array[i]: -1})
    model.add_reaction(temp_DM)
    
    # this part sets the newly created demand as the objective
    my_objective = model.reactions.get_by_id(str(temp_DM))
    model.change_objective(my_objective)
    
    # this part runs FBA on the new demand
    p_solution = model.optimize()
    
    # this stores the demand flux into a dictionary where its demand rxn is the key
    normal_maxmet_dict[str(temp_DM)] = p_solution.f
    
    # this deletes the demand at the end of each iteration
    model.reactions.get_by_id(str(temp_DM)).delete()

# %% [markdown]
# ## Calculating the gene KO demands

# %%
# Knocking out your gene

model.reactions.get_by_id(str(gene_name)).upper_bound = 0
model.reactions.get_by_id(str(gene_name)).lower_bound = 0

# %%
'''model.reactions.get_by_id('DM_amp_c').upper_bound = 0
model.reactions.get_by_id('DM_amp_c').lower_bound = 0
'''
model.reactions.get_by_id('DM_argsuc_c').upper_bound = 0
model.reactions.get_by_id('DM_argsuc_c').lower_bound = 0
'''
model.reactions.get_by_id('DM_h_c').upper_bound = 0
model.reactions.get_by_id('DM_h_c').lower_bound = 0

model.reactions.get_by_id('DM_ppi_c').upper_bound = 0
model.reactions.get_by_id('DM_ppi_c').lower_bound = 0'''
# Out:
# "\nmodel.reactions.get_by_id('DM_h_c').upper_bound = 0\nmodel.reactions.get_by_id('DM_h_c').lower_bound = 0\n\nmodel.reactions.get_by_id('DM_ppi_c').upper_bound = 0\nmodel.reactions.get_by_id('DM_ppi_c').lower_bound = 0"

# %%
# working copy!
# This creates an array of modified met names since I'm getting errors accessing model.metabolites[i].id in some of the code


newmet_array = [0] * len(model.metabolites)
met_count = 0
for i in range(len(model.metabolites)):
    newmet_array[met_count] = string.replace(model.metabolites[i].id, " ", "_")
    met_count = met_count + 1

# %%
# creates an empty dict to store DM_rxns as keys and the p_solution.f values
KO_maxmet_dict = {}

for i in range(len(model.metabolites)):
#for i in range(80):
    
    # this part creates a demand reaction for each metabolite
    temp_DM = 'DM_' + str(newmet_array[i])
    
    # this nested for loop tries to catch if a demand reaction already exists in the model
    for ii in model.reactions:
        if temp_DM == str(ii):
            # this part sets the newly created demand as the objective
            my_objective = model.reactions.get_by_id(str(temp_DM))
            model.change_objective(my_objective)

            # this part runs FBA on the new demand
            p_solution = model.optimize()

            # this stores the demand flux into a dictionary where its demand rxn is the key
            KO_maxmet_dict[str(temp_DM)] = p_solution.f

            # this deletes the demand at the end of each iteration
            model.reactions.get_by_id(str(temp_DM)).delete()
            
            
    temp_DM = Reaction(str(temp_DM))
    newmet_array[i] = model.metabolites.get_by_id(model.metabolites[i].id)
    temp_DM.add_metabolites({newmet_array[i]: -1})
    model.add_reaction(temp_DM)
    
    # this part sets the newly created demand as the objective
    my_objective = model.reactions.get_by_id(str(temp_DM))
    model.change_objective(my_objective)
    
    # this part runs FBA on the new demand
    p_solution = model.optimize()
    
    # this stores the demand flux into a dictionary where its demand rxn is the key
    KO_maxmet_dict[str(temp_DM)] = p_solution.f
    
    # this deletes the demand at the end of each iteration
    model.reactions.get_by_id(str(temp_DM)).delete()

# %% [markdown]
# ## Computing and normalizing the demands to generate metabolite scores

# %%
# This combines the normal_flux solutions and KO_flux solutions into one dictionary
# The same key, the reaction, and stores 2 flux values as a list to the dic key where [0] is normal and [1] is KO

combined_dic = {key: {'init_flux': normal_maxmet_dict[key], 'KO_flux': KO_maxmet_dict[key]}
                for key in KO_maxmet_dict if key in normal_maxmet_dict}

# %%
combined_dic
# Out:
# {'DM_vitd3_e': {'KO_flux': 0.06509703630581498,
#   'init_flux': 0.06509703723713756},
#  'DM_3mox4hoxm_c': {'KO_flux': 0.0051203531911596665,
#   'init_flux': 0.005120353191159666},
#  'DM_malcoa_m': {'KO_flux': 0.4711129207148529,
#   'init_flux': 0.48078809670835115},
#  'DM_vitd3_c': {'KO_flux': 0.06509703677147627,
#   'init_flux': 0.06509703710866215},
#  'DM_vitd3_m': {'KO_flux': 0.06509703578840428,
#   'init_flux': 0.0650970368866499},
#  'DM_fald_x': {'KO_flux': 1.5116440496662238, 'init_flux': 1.511644122311115},
#  'DM_malcoa_c': {'KO_flux': 0.46615382737945765,
#   'init_flux': 0.47454412260172657},
#  'DM_R1coa_hs_c': {'KO_flux': 0.1259523971330579,
#   'init_flux': 0.12599490814274283},
#  'DM_malttr_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_adprib_m': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_adprib_c': {'KO_flux': 0.2010436539692749,
#   'init_flux': 0.21297167324373895},
#  'DM_f1p_c': {'KO_flux': 0.5026440680182355, 'init_flux': 0.5026440764965366},
#  'DM_R1coa_hs_r': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_for_n': {'KO_flux': 1.009079828276299, 'init_flux': 1.0090798114300321},
#  'DM_malttr_l': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_adprib_e': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_3mob_c': {'KO_flux': 0.001075694221071899,
#   'init_flux': 0.0010756943374872208},
#  'DM_3mob_m': {'KO_flux': 0.0010756943374872208,
#   'init_flux': 0.0010756943374872208},
#  'DM_m_em_3gacpail_hs_r': {'KO_flux': 0.02557802512211941,
#   'init_flux': 0.02557802526065471},
#  'DM_od2coa_m': {'KO_flux': 0.11010408270934641,
#   'init_flux': 0.11014124308077822},
#  'DM_ksii_core2_deg3_l': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_od2coa_c': {'KO_flux': 0.1101040793582797,
#   'init_flux': 0.11014124458714127},
#  'DM_quln_c': {'KO_flux': 0.0005947064021377133,
#   'init_flux': 0.0005947081372141838},
#  'DM_5mthf_e': {'KO_flux': 1.949034382473187e-10,
#   'init_flux': -1.1641532182693481e-10},
#  'DM_ksii_core2_deg1_l': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_5mthf_c': {'KO_flux': -1.1641532182693481e-10, 'init_flux': 0.0},
#  'DM_b2coa_m': {'KO_flux': 0.3542769123897979,
#   'init_flux': 0.3617811656363383},
#  'DM_b2coa_x': {'KO_flux': 0.340336408582516,
#   'init_flux': 0.34045093483291566},
#  'DM_ksii_core2_deg7_l': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_m5mpdol__L_r': {'KO_flux': -9.068824848539885e-27, 'init_flux': 0.0},
#  'DM_q10_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_cgly_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_dttp_c': {'KO_flux': 0.276855879546554, 'init_flux': 0.28109977584196794},
#  'DM_acgam6p_c': {'KO_flux': 0.3750909573627978,
#   'init_flux': 0.3797531411983073},
#  'DM_dedol__L_c': {'KO_flux': 2.168404344971009e-20, 'init_flux': 0.0},
#  'DM_3dpdhb_me_m': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_n2m2nmasn_g': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_acglcgalacglcgal14acglcgalgluside_hs_g': {'KO_flux': 2.5393658904854735e-10,
#   'init_flux': 3.8805107275645014e-11},
#  'DM_3hbcoa_m': {'KO_flux': 0.354276910505011,
#   'init_flux': 0.3574152832152322},
#  'DM_hs_deg1_l': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_3mop_m': {'KO_flux': 0.0024393098428845406,
#   'init_flux': 0.0024393098428845406},
#  'DM_retfa_e': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_xoltri27_e': {'KO_flux': 0.06408621335867792,
#   'init_flux': 0.06408621452283114},
#  'DM_3mop_c': {'KO_flux': 0.0024393098428845406,
#   'init_flux': 0.0024393098428845406},
#  'DM_3hbcoa_x': {'KO_flux': 0.3403363978236237,
#   'init_flux': 0.3404509324764531},
#  'DM_air_c': {'KO_flux': 0.36326385242578, 'init_flux': 0.37643332394304796},
#  'DM_gdpddman_c': {'KO_flux': 0.19676613372800533,
#   'init_flux': 0.19676612896976414},
#  'DM_ksii_core2_deg4_l': {'KO_flux': 1.1280563046974487e-11, 'init_flux': 0.0},
#  'DM_glx_x': {'KO_flux': 1.1068322112113245, 'init_flux': 2.0705327173168495},
#  'DM_mhista_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_ksii_core2_deg8_l': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_glx_c': {'KO_flux': 1.1068322114457347, 'init_flux': 1.1068322075238652},
#  'DM_hspg_e': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_glx_m': {'KO_flux': 1.1068322031088371, 'init_flux': 2.0705326645402238},
#  'DM_hspg_g': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_lneldccoa_c': {'KO_flux': 0.10831085346585566,
#   'init_flux': 0.10834741111343754},
#  'DM_Nmelys_n': {'KO_flux': 1.0, 'init_flux': 1.0000000028218994},
#  'DM_lneldccoa_m': {'KO_flux': 0.10831085156274235,
#   'init_flux': 0.1083108540920038},
#  'DM_dgsn_l': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_dgsn_m': {'KO_flux': 0.3101466164064312, 'init_flux': 0.3250594549804317},
#  'DM_oh1_m': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_oh1_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_dgsn_c': {'KO_flux': 0.3101466164064312, 'init_flux': 0.3250594549804317},
#  'DM_dgsn_e': {'KO_flux': 0.3101466133957729, 'init_flux': 0.3250594532582909},
#  'DM_oh1_e': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_3odcoa_x': {'KO_flux': -1.1555482209798177e-18, 'init_flux': 0.0},
#  'DM_acgalfucgalacglcgal14acglcgalgluside_hs_g': {'KO_flux': 0.0,
#   'init_flux': 0.0},
#  'DM_aldstrn_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_s2l2n2m2mn_l': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_aldstrn_e': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_pydx5p_m': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_leuktrB4wcooh_r': {'KO_flux': -6.464140760231122e-21,
#   'init_flux': 3.8163947689518067e-19},
#  'DM_ksi_pre27_g': {'KO_flux': 2.407144745150624e-19, 'init_flux': 0.0},
#  'DM_pydx5p_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_aldstrn_m': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_dmnoncoa_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_prostgf2_e': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_prostgf2_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_emem2gacpail_hs_r': {'KO_flux': 0.02768645458169939,
#   'init_flux': 0.02768645534524694},
#  'DM_tolbutamide_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_acmana_c': {'KO_flux': 0.3671103098895401,
#   'init_flux': 0.37167330949039246},
#  'DM_adp_r': {'KO_flux': 0.3101466107844352, 'init_flux': 0.33463453781569785},
#  'DM_adp_m': {'KO_flux': 0.304575415328145, 'init_flux': 0.3387408349663019},
#  'DM_adp_n': {'KO_flux': 0.31014661490917206, 'init_flux': 0.3346345409579026},
#  'DM_m4masn_g': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_ksi_pre25_g': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_adp_e': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_ethamp_r': {'KO_flux': 0.8693644409657979,
#   'init_flux': 0.9271008008328258},
#  'DM_adp_c': {'KO_flux': 0.3101466164408676, 'init_flux': 0.33874082485480045},
#  'DM_ksii_core2_pre9_g': {'KO_flux': -2.5849394142282155e-26,
#   'init_flux': 0.0},
#  'DM_dedoldp_U_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_7dhf_m': {'KO_flux': 0.0, 'init_flux': -1.1641532182693484e-10},
#  'DM_glc__D_e': {'KO_flux': 0.5174277269333405, 'init_flux': 0.52354865684174},
#  'DM_glc__D_g': {'KO_flux': 0.5174277207042426,
#   'init_flux': 0.517427733391094},
#  'DM_thyox__L_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_thyox__L_e': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_galthcrm_hs_g': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_aflatoxin_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_mi14p_n': {'KO_flux': 0.4493436836868291,
#   'init_flux': 0.44934368529357016},
#  'DM_prist_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_prist_x': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_cdp_n': {'KO_flux': 0.3402699630949936, 'init_flux': 0.34749425544203844},
#  'DM_ksii_core4_deg3_l': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_cdp_c': {'KO_flux': 0.340269969180575, 'init_flux': 0.347494266461581},
#  'DM_lald__D_c': {'KO_flux': 0.8526008357848796,
#   'init_flux': 0.8632732184023322},
#  'DM_l2xser_g': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_ca2_e': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_ca2_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_11docrtstrn_m': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_g1m7masnC_g': {'KO_flux': 0.0, 'init_flux': -2.3283064365386963e-10},
#  'DM_11docrtstrn_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_na1_c': {'KO_flux': 0.9999999962747097, 'init_flux': 1.0000000018626451},
#  'DM_na1_e': {'KO_flux': 1.0000000081490725, 'init_flux': 1.0000000037252903},
#  'DM_na1_g': {'KO_flux': 1.0000000009313224, 'init_flux': 0.9999999981373549},
#  'DM_cs_c_deg3_l': {'KO_flux': -4.025479484300878e-33, 'init_flux': 0.0},
#  'DM_na1_x': {'KO_flux': 1.0, 'init_flux': 0.9999999946448952},
#  'DM_val__L_m': {'KO_flux': 0.001075694221071899,
#   'init_flux': 0.0010756943374872208},
#  'DM_11docrtstrn_r': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_ppmi1346p_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_g1m7masnC_r': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_val__L_e': {'KO_flux': 0.0010756943374872208,
#   'init_flux': 0.0010756943374872208},
#  'DM_ethamp_c': {'KO_flux': 1.0274129032993589,
#   'init_flux': 1.0274129044264555},
#  'DM_akgp_hs_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_dhap_x': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_retinol_9_cis_e': {'KO_flux': -7.562017440861492e-11, 'init_flux': 0.0},
#  'DM_dhap_c': {'KO_flux': 0.9779832971932773, 'init_flux': 0.9902251368048915},
#  'DM_mi13p_c': {'KO_flux': 0.4263004151934915,
#   'init_flux': 0.4263004232383401},
#  'DM_gt1c_hs_g': {'KO_flux': 8.326672684688677e-16,
#   'init_flux': -7.891245603985422e-16},
#  'DM_ksii_core2_pre2_g': {'KO_flux': 0.0,
#   'init_flux': -3.6379788070917155e-11},
#  'DM_malttr_e': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_cs_c_deg1_l': {'KO_flux': 0.0, 'init_flux': -2.569273114748037e-26},
#  'DM_trypta_c': {'KO_flux': 0.0005947081372141838,
#   'init_flux': 0.0005947081372141838},
#  'DM_but_m': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_sphs1p_r': {'KO_flux': 0.11739222036321255,
#   'init_flux': 0.11739222123287618},
#  'DM_but_e': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_6pgc_r': {'KO_flux': 0.5398229875136167, 'init_flux': 0.5398229984514005},
#  'DM_but_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_sphs1p_e': {'KO_flux': 0.1173922207672149,
#   'init_flux': 0.11739221983589232},
#  'DM_pppi_m': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_pppi_n': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_taxol_e': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_pppi_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_6pgc_c': {'KO_flux': 0.5398229876815074, 'init_flux': 0.539822984719649},
#  'DM_taxol_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_apoC_Lys_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_apoC_Lys_m': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_asp__L_e': {'KO_flux': 0.0081, 'init_flux': 0.0081},
#  'DM_asp__L_c': {'KO_flux': 0.8493305646177648,
#   'init_flux': 1.095592580874823},
#  'DM_eaflatoxin_e': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_asp__L_m': {'KO_flux': 0.8493305391276482,
#   'init_flux': 1.0955925320771447},
#  'DM_gd1b2_hs_e': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_ksii_core2_pre4_g': {'KO_flux': 0.0, 'init_flux': 3.4924596548080456e-11},
#  'DM_gd1b2_hs_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_eaflatoxin_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_hco3_c': {'KO_flux': 3.3973221853375435, 'init_flux': 5.442322207149118},
#  'DM_44mzym_r': {'KO_flux': 0.06649546905641648,
#   'init_flux': 0.06842668992723734},
#  'DM_hco3_e': {'KO_flux': 3.3973222337663174, 'init_flux': 5.442322228103876},
#  'DM_caro_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_caro_e': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_2mcacn_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_tag_hs_e': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_tag_hs_c': {'KO_flux': 0.04192412365227938,
#   'init_flux': 0.041941140933583254},
#  'DM_6pthp_c': {'KO_flux': 0.32815512514780915,
#   'init_flux': 0.3281551348957735},
#  'DM_3hibutcoa_m': {'KO_flux': 0.0010756943374872208,
#   'init_flux': 0.0010756943374872208},
#  'DM_6pthp_n': {'KO_flux': 0.32815513340756297,
#   'init_flux': 0.32815512851811945},
#  'DM_cs_e_pre5b_g': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_3ohodcoa_x': {'KO_flux': -2.1633954482156825e-24, 'init_flux': 0.0},
#  'DM_fuc__L_l': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_ksi_pre22_g': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_g1m8masn_r': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_gd1b_hs_g': {'KO_flux': 0.0, 'init_flux': -2.0061770254033706e-36},
#  'DM_fuc__L_e': {'KO_flux': 0.0, 'init_flux': 5.497390197383052e-11},
#  'DM_fuc__L_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_cspg_e_l': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_pepslys_r': {'KO_flux': 0.4565966265474277,
#   'init_flux': 0.4565966346215435},
#  'DM_cspg_e_g': {'KO_flux': -5.437919842975726e-34, 'init_flux': 0.0},
#  'DM_cspg_e_e': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_T_antigen_g': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_g1m8masn_g': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_fol_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_2425dhvitd3_m': {'KO_flux': 0.06441964755173434,
#   'init_flux': 0.06559178511961364},
#  'DM_sucr_e': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_2425dhvitd3_e': {'KO_flux': 0.06441964802729382,
#   'init_flux': 0.06559178606596913},
#  'DM_cpppg3_c': {'KO_flux': 0.06917701286665953,
#   'init_flux': 0.08079624418178061},
#  'DM_2425dhvitd3_c': {'KO_flux': 0.06441964790892685,
#   'init_flux': 0.06559178511961364},
#  'DM_bildglcur_c': {'KO_flux': 0.05534160940442234,
#   'init_flux': 0.06045186705887318},
#  'DM_dudp_n': {'KO_flux': 0.33039116501458904,
#   'init_flux': 0.3371040695346892},
#  'DM_lyxnt_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_lnlc_c': {'KO_flux': 0.0, 'init_flux': 3.479214327944737e-25},
#  'DM_cspg_a_l': {'KO_flux': -2.2331390049358486e-25, 'init_flux': 0.0},
#  'DM_cspg_a_g': {'KO_flux': 0.0, 'init_flux': -3.621810012393521e-11},
#  'DM_acn23acngalgbside_hs_g': {'KO_flux': -8.31538013049535e-12,
#   'init_flux': 0.0},
#  'DM_cspg_a_e': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_fadh2_x': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_m3gacpail_hs_r': {'KO_flux': 0.02929641536436975,
#   'init_flux': 0.02929641601319124},
#  'DM_fadh2_r': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_cspg_c_e': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_cspg_c_g': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_biocyt_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_btn_m': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_fadh2_m': {'KO_flux': 0.0, 'init_flux': -1.3586890152943188e-10},
#  'DM_btn_n': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_1a25dhvitd3_m': {'KO_flux': 0.06441964683514159,
#   'init_flux': 0.06559178403163567},
#  'DM_btn_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_fadh2_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_btn_e': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_forglu_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_ade_c': {'KO_flux': 0.652103789607664, 'init_flux': 0.74518017238006},
#  'DM_ade_e': {'KO_flux': 0.6521037774239161, 'init_flux': 0.7451801537536085},
#  'DM_id3acald_c': {'KO_flux': 0.0005947081372141838,
#   'init_flux': 0.0005947081372141838},
#  'DM_glygn5_e': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_mem2emgacpail_prot_hs_r': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_ade_l': {'KO_flux': 0.6521037858589978, 'init_flux': 0.7451801567519861},
#  'DM_glu__L_m': {'KO_flux': 0.6353931669145823,
#   'init_flux': 0.7220787858925405},
#  'DM_dudp_c': {'KO_flux': 0.33039116397654955,
#   'init_flux': 0.3371040695346892},
#  'DM_dnad_m': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_dnad_n': {'KO_flux': 0.0005947081372141832,
#   'init_flux': 0.0005946690935449466},
#  'DM_dnad_c': {'KO_flux': 0.0005947081372141832,
#   'init_flux': 0.0005946690935449466},
#  'DM_tchola_x': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_gd3_hs_g': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_tchola_e': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_tchola_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_gd3_hs_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_acorn_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_leuktrE4_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_gdp_c': {'KO_flux': 0.3188968334028323, 'init_flux': 0.3387408126880349},
#  'DM_orn__D_x': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_co2_x': {'KO_flux': 3.3973223047796637, 'init_flux': 5.397322259261273},
#  'DM_dhea_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_s2l2n2m2masn_l': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_m8mpdol__L_r': {'KO_flux': 0.0, 'init_flux': 6.3755168072904315e-21},
#  'DM_s2l2n2m2masn_e': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_fucgal14acglcgalgluside_hs_c': {'KO_flux': 0.0,
#   'init_flux': 4.656612873077393e-10},
#  'DM_dhea_r': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_fucgal14acglcgalgluside_hs_g': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_fucgal14acglcgalgluside_hs_e': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_5fthf_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_glu5sa_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_5fthf_e': {'KO_flux': -2.3283064365386963e-10, 'init_flux': 0.0},
#  'DM_glu5sa_m': {'KO_flux': 0.5934400163535912,
#   'init_flux': 0.5934400146907176},
#  'DM_34dhpac_c': {'KO_flux': 0.005120353191159666,
#   'init_flux': 0.005120353191159666},
#  'DM_dolichol_U_r': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_ksi_pre28_g': {'KO_flux': 7.989286792044544e-12,
#   'init_flux': -2.243176908590699e-19},
#  'DM_cysam_c': {'KO_flux': -5.339306636668543e-09, 'init_flux': 0.0},
#  'DM_acglcgalgbside_hs_g': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_im4ac_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_cs_e_pre3_g': {'KO_flux': -1.8807909613156592e-37, 'init_flux': 0.0},
#  'DM_im4ac_m': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_dolichol_U_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_xoltetrol_m': {'KO_flux': 0.0630403195526776,
#   'init_flux': 0.06304032019777726},
#  'DM_m2mn_l': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_dsT_antigen_g': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_pydx_e': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_4nph_e': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_dctp_c': {'KO_flux': 0.318078450509347, 'init_flux': 0.3241799515112244},
#  'DM_Rtotal2_e': {'KO_flux': 0.13189974417544512,
#   'init_flux': 0.13189974654959227},
#  'DM_ptdca_e': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_crtstrn_r': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_dctp_n': {'KO_flux': 0.318078447651815, 'init_flux': 0.32417996088042855},
#  'DM_dctp_m': {'KO_flux': 0.3122602447401732, 'init_flux': 0.324179956009261},
#  'DM_ppmi12346p_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_cholp_l': {'KO_flux': 0.34251881905868, 'init_flux': 0.48919152980670333},
#  'DM_4h2oglt_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_whhdca_c': {'KO_flux': 0.1293830038048327,
#   'init_flux': 0.1293830059003085},
#  'DM_3hpcoa_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_5g2oxpt_x': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_cit_e': {'KO_flux': 0.5662203864194453, 'init_flux': 0.6930142496712506},
#  'DM_fuc14galacglcgalgluside_hs_e': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_adn_l': {'KO_flux': 0.31592605959006176,
#   'init_flux': 0.35196896060184735},
#  'DM_chol_c': {'KO_flux': 0.3495810655876994, 'init_flux': 0.5040155247752763},
#  'DM_chol_e': {'KO_flux': 0.3495810652675573, 'init_flux': 0.5101518863812089},
#  'DM_cit_c': {'KO_flux': 0.5662203718169851, 'init_flux': 0.7018324231030438},
#  'DM_chol_g': {'KO_flux': 0.34958106619567797,
#   'init_flux': 0.5040155213216074},
#  'DM_cit_m': {'KO_flux': 0.5662203734663547, 'init_flux': 0.7018324153013554},
#  'DM_adn_e': {'KO_flux': 0.31592605798505247, 'init_flux': 0.3519689561443048},
#  'DM_pail_hs_n': {'KO_flux': 0.0542437715921551,
#   'init_flux': 0.05424377240110333},
#  'DM_chol_n': {'KO_flux': 0.34958106209523976,
#   'init_flux': 0.5040155156292102},
#  'DM_pail_hs_r': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_chol_r': {'KO_flux': 0.3495810602325946, 'init_flux': 0.5040155195392263},
#  'DM_pre_prot_r': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_apoC_m': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_co2_m': {'KO_flux': 3.397322147618979, 'init_flux': 5.442322292830795},
#  'DM_apoC_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_4hdebrisoquine_e': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_4hdebrisoquine_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_g6p_r': {'KO_flux': 0.5030689068292253, 'init_flux': 0.5032339549095954},
#  'DM_mmcoa__S_x': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_co2_n': {'KO_flux': 3.3973222905769944, 'init_flux': 5.397322259377688},
#  'DM_4hbzcoa_m': {'KO_flux': -9.682055504556253e-14, 'init_flux': 0.0},
#  'DM_gln__L_c': {'KO_flux': 0.6228111099335365,
#   'init_flux': 0.6993063003310362},
#  'DM_glc2man_g': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_g6p_c': {'KO_flux': 0.5030689146369696, 'init_flux': 0.5030689015799531},
#  'DM_gln__L_e': {'KO_flux': 0.6228111114059219,
#   'init_flux': 0.6993061810730379},
#  'DM_gncore2_g': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_akg_x': {'KO_flux': 0.672844116576016, 'init_flux': 0.7720156607749731},
#  'DM_3pg_c': {'KO_flux': 1.1068322036881, 'init_flux': 1.2157462875788543},
#  'DM_mmcoa__S_m': {'KO_flux': 0.39398946269678553,
#   'init_flux': 0.3939894717811353},
#  'DM_glygn1_c': {'KO_flux': 0.04442686469296671,
#   'init_flux': 0.04442686419321175},
#  'DM_xoldiolone_c': {'KO_flux': 0.06441964954137802,
#   'init_flux': 0.06559178489260375},
#  'DM_xoldiolone_m': {'KO_flux': 0.06441964814439416,
#   'init_flux': 0.06441964791156352},
#  'DM_m1mpdol__L_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_6htststerone_r': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_glygn3_c': {'KO_flux': 0.06841737105285312,
#   'init_flux': 0.06841737064792934},
#  'DM_xoldiolone_r': {'KO_flux': 0.06441964698024094,
#   'init_flux': 0.06441964814439416},
#  'DM_gm1a_hs_g': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_m8mpdol_U_r': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_cs_c_deg4_l': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_m7masnC_g': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_nrvnccoa_m': {'KO_flux': -2.0679515313825692e-25, 'init_flux': 0.0},
#  'DM_lnlncacrn_c': {'KO_flux': -3.916686772206343e-25,
#   'init_flux': -3.446585885638031e-26},
#  'DM_lnlncacrn_m': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_lxser_g': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_lac__L_e': {'KO_flux': 1.0848646827539414,
#   'init_flux': 1.084864666918308},
#  'DM_ctp_n': {'KO_flux': 0.33361973756716695, 'init_flux': 0.3404977440232766},
#  'DM_ctp_m': {'KO_flux': 0.32722446979356024, 'init_flux': 0.3337773858802393},
#  'DM_ctp_c': {'KO_flux': 0.3336197483243008, 'init_flux': 0.34049773700377167},
#  'DM_biliverd_c': {'KO_flux': 0.0691770124622951,
#   'init_flux': 0.0779843099298887},
#  'DM_s2l2n2m2m_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_fuc1p__L_c': {'KO_flux': 0.46919734333641827,
#   'init_flux': 0.4691973537084104},
#  'DM_cs_d_pre2_g': {'KO_flux': -1.178705133497715e-10, 'init_flux': 0.0},
#  'DM_m7masnA_g': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_s2l2n2m2m_l': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_ppcoa_m': {'KO_flux': 0.39403263927081844,
#   'init_flux': 0.4000105686511361},
#  'DM_xol7ah2_c': {'KO_flux': 0.06408621246677748,
#   'init_flux': 0.06501641890220361},
#  'DM_arachcoa_x': {'KO_flux': 0.0, 'init_flux': -1.5976529391229116e-18},
#  'DM_pgp_hs_c': {'KO_flux': 0.056743058408707914,
#   'init_flux': 0.05674305953044284},
#  'DM_cs_d_deg4_l': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_ficytC_m': {'KO_flux': -8.881784197001252e-16, 'init_flux': 0.0},
#  'DM_phom_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_ppcoa_x': {'KO_flux': 0.05574630316421919,
#   'init_flux': 0.0558408789939691},
#  'DM_cs_d_deg6_l': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_acngalacglcgal14acglcgalgluside_hs_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_cca_d3_m': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_acngalacglcgal14acglcgalgluside_hs_g': {'KO_flux': 0.0,
#   'init_flux': -1.1641532182693481e-10},
#  'DM_glyb_c': {'KO_flux': 0.38100407633464783,
#   'init_flux': 0.5735349023847589},
#  'DM_glyb_m': {'KO_flux': 0.38100407633464783,
#   'init_flux': 0.5735349023847589},
#  'DM_cca_d3_e': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_R3coa_hs_c': {'KO_flux': 0.12595239392248914,
#   'init_flux': 0.12599490704620225},
#  'DM_dolglcp__L_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_pac_c': {'KO_flux': 0.0009778488893061874,
#   'init_flux': 0.0009778488893061876},
#  'DM_4hoxpacd_c': {'KO_flux': 0.005120353191159666,
#   'init_flux': 0.005120353191159666},
#  'DM_pylald_m': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_tststerones_e': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_kdn_c': {'KO_flux': 0.35660087863530876, 'init_flux': 0.3572303737222128},
#  'DM_tststerones_c': {'KO_flux': 2.328306436538697e-10, 'init_flux': 0.0},
#  'DM_pylald_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_hpdca_e': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_ser__L_e': {'KO_flux': 1.106832211507326,
#   'init_flux': 1.2740176875377074},
#  'DM_hpdca_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_hdcoa_m': {'KO_flux': 0.12361127112617043,
#   'init_flux': 0.12365299509099084},
#  'DM_ttdcrn_c': {'KO_flux': -2.941086622411971e-24,
#   'init_flux': -4.1359030627651375e-25},
#  'DM_3mox4hpac_c': {'KO_flux': 0.005120353191159666,
#   'init_flux': 0.005120353307574987},
#  'DM_ttdcrn_m': {'KO_flux': -8.2718061255246895e-25,
#   'init_flux': -4.1359030627651375e-25},
#  'DM_hdcoa_c': {'KO_flux': 0.12361127299900873,
#   'init_flux': 0.1236529964207402},
#  'DM_emgacpail_hs_r': {'KO_flux': 0.032095977173109226,
#   'init_flux': 0.03209597702165014},
#  'DM_ser__L_x': {'KO_flux': 1.1068322488852467,
#   'init_flux': 1.1068321967031813},
#  'DM_fucgalacgalfuc12gal14acglcgalgluside_hs_g': {'KO_flux': 0.0,
#   'init_flux': 2.3283064365386963e-10},
#  'DM_dag_hs_e': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_acglu_m': {'KO_flux': 0.4368327986449003,
#   'init_flux': 0.5006413180031257},
#  'DM_dag_hs_c': {'KO_flux': 0.06145866276638392,
#   'init_flux': 0.06148360810215148},
#  'DM_dag_hs_n': {'KO_flux': 0.061238107895676804,
#   'init_flux': 0.06125877716112882},
#  'DM_xol7ah3_m': {'KO_flux': 0.06362510994721515,
#   'init_flux': 0.06362510973263248},
#  'DM_dag_hs_r': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_lys__L_n': {'KO_flux': 0.0013169089797884226,
#   'init_flux': 0.0013169089797884226},
#  'DM_acgalfucgalacgalfuc12gal14acglcgalgluside_hs_e': {'KO_flux': 0.0,
#   'init_flux': 0.0},
#  'DM_acgalfucgalacgalfuc12gal14acglcgalgluside_hs_g': {'KO_flux': 0.0,
#   'init_flux': 1.1641532182693481e-10},
#  'DM_acgalfucgalacgalfuc12gal14acglcgalgluside_hs_c': {'KO_flux': 0.0,
#   'init_flux': 0.0},
#  'DM_dad_5_e': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_citr__L_m': {'KO_flux': 0.4947991041123621,
#   'init_flux': 0.5384129521459259},
#  'DM_zym_int2_r': {'KO_flux': 0.06614025807917584,
#   'init_flux': 0.06780436827578373},
#  'DM_bvite_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_bvite_e': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_co_e': {'KO_flux': 0.06917701370548457, 'init_flux': 0.07708999433089048},
#  'DM_9_cis_retfa_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_n2m2nm_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_9_cis_retfa_e': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_co_c': {'KO_flux': 0.06917701307461921, 'init_flux': 0.0770899954950437},
#  'DM_thcholst_m': {'KO_flux': 0.06362510970863114,
#   'init_flux': 0.06362511050732175},
#  'DM_n2m2nm_l': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_3dsphgn_c': {'KO_flux': 0.11983789258546378,
#   'init_flux': 0.12140857799637875},
#  'DM_galgalgalthcrm_hs_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_prostge2_e': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_galgalgalthcrm_hs_g': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_prostge2_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_galgalgalthcrm_hs_e': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_core2_g': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_tymsf_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_tymsf_e': {'KO_flux': -5.970120448353655e-12, 'init_flux': 0.0},
#  'DM_ptrc_c': {'KO_flux': 0.5419228276005015, 'init_flux': 0.5419228324816983},
#  'DM_ptrc_m': {'KO_flux': 6.904394831508398e-05,
#   'init_flux': 0.010069043948315084},
#  'DM_apoC_Lys_btn_m': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_ksi_deg8_l': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_glyc__R_c': {'KO_flux': 0.9971948854942414,
#   'init_flux': 0.9971948816906658},
#  'DM_ha_deg1_l': {'KO_flux': 0.13612769465036242,
#   'init_flux': 0.13612769002285416},
#  'DM_cs_pre_g': {'KO_flux': 2.771793376831786e-12, 'init_flux': 0.0},
#  'DM_melatn_c': {'KO_flux': 0.0005947081372141838,
#   'init_flux': 0.0005947081372141838},
#  'DM_galacglcgalgluside_hs_g': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_hs_pre13_g': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_dtdp_m': {'KO_flux': 0.27685616293456405,
#   'init_flux': 0.28585076064337045},
#  'DM_dtdp_n': {'KO_flux': 0.28141944281359516,
#   'init_flux': 0.28585075843147933},
#  'DM_dtdp_c': {'KO_flux': 0.2814194385059686, 'init_flux': 0.2858507560110478},
#  'DM_xser_r': {'KO_flux': -9.978456156594439e-12, 'init_flux': 0.0},
#  'DM_doldp__L_r': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_crtstrn_m': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_galfuc12gal14acglcgalgluside_hs_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_dlnlcgcrn_c': {'KO_flux': -7.625571271973216e-25, 'init_flux': 0.0},
#  'DM_galfuc12gal14acglcgalgluside_hs_g': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_acgam_l': {'KO_flux': 0.34613476239610463,
#   'init_flux': 0.35108754762545086},
#  'DM_ksii_core4_pre1_g': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_hs_pre11_g': {'KO_flux': -2.3523241607020205e-11, 'init_flux': 0.0},
#  'DM_acgam_c': {'KO_flux': 0.3671103078440177,
#   'init_flux': 0.37167328247856857},
#  'DM_2hb_c': {'KO_flux': 0.993309329263866, 'init_flux': 0.993309329263866},
#  'DM_2hb_e': {'KO_flux': 0.993309329263866, 'init_flux': 0.993309329263866},
#  'DM_dlnlcgcrn_m': {'KO_flux': 0.0, 'init_flux': -5.820766096316013e-11},
#  'DM_acgam_e': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_man_e': {'KO_flux': 0.0, 'init_flux': 1.6538010206241431e-10},
#  'DM_ksii_core2_g': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_man_g': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_ksii_core2_e': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_cdpchol_c': {'KO_flux': 0.16959714790630662,
#   'init_flux': 0.20474505956939823},
#  'DM_man_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_lys__L_e': {'KO_flux': 0.0013169089797884226,
#   'init_flux': 0.0013169089797884226},
#  'DM_man_l': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_ksii_core2_l': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_oagd3_hs_g': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_2mp2coa_m': {'KO_flux': 0.0010756934061646461,
#   'init_flux': 0.00107569433748722},
#  'DM_mi34p_c': {'KO_flux': 0.4263004124004382,
#   'init_flux': 0.4263004157692194},
#  'DM_oagd3_hs_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_ksii_core4_e': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_4mop_c': {'KO_flux': 0.0012881513684988022,
#   'init_flux': 0.0012881513684988022},
#  'DM_g1m6masnB1_r': {'KO_flux': -1.5612511283791264e-17, 'init_flux': 0.0},
#  'DM_pecgoncoa_r': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_pydam_e': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_ksii_core4_l': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_17ahprgstrn_r': {'KO_flux': 0.0, 'init_flux': 2.889510729339676e-26},
#  'DM_ksi_deg28_l': {'KO_flux': 0.0, 'init_flux': 3.880510870542867e-11},
#  'DM_dolmanp__L_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_ksi_deg26_l': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_chol_m': {'KO_flux': 0.3495810590684414, 'init_flux': 0.5040155326904994},
#  'DM_ak2lgchol_hs_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_dolmanp__L_r': {'KO_flux': 0.0, 'init_flux': 1.1641532182693482e-11},
#  'DM_ak2lgchol_hs_e': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_ksi_deg24_l': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_34dhoxpeg_c': {'KO_flux': 0.005120353191159666,
#   'init_flux': 0.005120353191159666},
#  'DM_34dhoxpeg_e': {'KO_flux': 0.005120353191159666,
#   'init_flux': 0.005120353191159666},
#  'DM_so3_m': {'KO_flux': 0.0, 'init_flux': -3.665983307990102e-10},
#  'DM_xylu__L_c': {'KO_flux': 0.5534160907693388,
#   'init_flux': 0.5705122321536117},
#  'DM_fald_m': {'KO_flux': 0.8763061694915297, 'init_flux': 1.5868324829223173},
#  'DM_fald_l': {'KO_flux': 0.8763061762503862, 'init_flux': 0.8763061813078821},
#  'DM_for_r': {'KO_flux': 1.009079828276299, 'init_flux': 1.0090798114300321},
#  'DM_dgpi_prot_hs_r': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_nrpphr_e': {'KO_flux': 0.005120353307574987,
#   'init_flux': 0.005120353307574987},
#  'DM_R6coa_hs_c': {'KO_flux': 0.12453720031771809,
#   'init_flux': 0.12457923292769357},
#  'DM_fald_c': {'KO_flux': 0.8763061762503862, 'init_flux': 1.5974903961177915},
#  'DM_nrpphr_c': {'KO_flux': 0.005120353307574987,
#   'init_flux': 0.0051203531911596665},
#  'DM_prgnlone_m': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_for_e': {'KO_flux': 1.0090798355140573, 'init_flux': 1.8272616452015078},
#  'DM_for_c': {'KO_flux': 1.0090798281598836, 'init_flux': 1.827261652215384},
#  'DM_m3mpdol_U_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_for_m': {'KO_flux': 1.009079828276299, 'init_flux': 1.0090798114300321},
#  'DM_carveol_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_carveol_e': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_pglyc_hs_e': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_dedoldp__L_c': {'KO_flux': -2.168404344971009e-20, 'init_flux': 0.0},
#  'DM_3amp_l': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_g2m8mpdol_U_r': {'KO_flux': 2.944118420312899e-27, 'init_flux': 0.0},
#  'DM_formcoa_c': {'KO_flux': 0.0, 'init_flux': -6.319659879905128e-22},
#  'DM_hspg_l': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_m5masnB2_g': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_whddca_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_formcoa_x': {'KO_flux': 0.0, 'init_flux': -6.319659879905128e-22},
#  'DM_4tmeabut_m': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_apnnox_e': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_galt_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_4tmeabut_c': {'KO_flux': 9.129544977652429e-27,
#   'init_flux': 7.522173695404285e-25},
#  'DM_apnnox_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_phe__L_m': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_3padsel_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_phe__L_e': {'KO_flux': 0.0009778488893061876,
#   'init_flux': 0.0009778488893061876},
#  'DM_ksi_deg15_l': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_btcoa_m': {'KO_flux': -1.0377831204511927e-16, 'init_flux': 0.0},
#  'DM_2dr1p_c': {'KO_flux': 0.5334454403718848, 'init_flux': 0.540122813533243},
#  'DM_hmgcoa_x': {'KO_flux': 0.30753204408608176,
#   'init_flux': 0.30753204106099563},
#  'DM_andrstndn_r': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_lac__D_e': {'KO_flux': 1.0848646672675386,
#   'init_flux': 1.1032114239920312},
#  'DM_lnlnca_c': {'KO_flux': -4.883612678876888e-27,
#   'init_flux': -6.946665546214414e-12},
#  'DM_ksi_deg11_l': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_lnlnca_e': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_12HPET_c': {'KO_flux': 0.0, 'init_flux': -3.6532049926941663e-19},
#  'DM_coucoa_m': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_mma_c': {'KO_flux': 0.005120353191159666,
#   'init_flux': 0.005120353191159666},
#  'DM_pser__L_c': {'KO_flux': 1.1068322058059405,
#   'init_flux': 1.1068321999049495},
#  'DM_lnlncg_c': {'KO_flux': 0.0, 'init_flux': -3.6763582780134557e-25},
#  'DM_lnlncg_e': {'KO_flux': -9.223412117579461e-21,
#   'init_flux': -2.3507483219990113e-25},
#  'DM_ksi_pre13_g': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_omeprazole_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_omeprazole_e': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_Rtotal2_c': {'KO_flux': 0.1318997426832127,
#   'init_flux': 0.13354943234070163},
#  'DM_ksi_pre15_g': {'KO_flux': 0.0, 'init_flux': -1.1930489604130218e-26},
#  'DM_1mncam_e': {'KO_flux': 0.0005947081372141787,
#   'init_flux': 0.000594709999859333},
#  'DM_estradiolglc_r': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_urate_e': {'KO_flux': 0.679464432044897, 'init_flux': 0.6794649248819703},
#  'DM_Lcystin_e': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_Lcystin_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_thym_e': {'KO_flux': 0.5787382846147834, 'init_flux': 0.5787382910346022},
#  'DM_thym_c': {'KO_flux': 0.5787382903508842, 'init_flux': 0.6040298789755607},
#  'DM_ksi_pre11_g': {'KO_flux': 1.967759325682675e-11, 'init_flux': 0.0},
#  'DM_arach_c': {'KO_flux': -7.124105336387023e-19,
#   'init_flux': 8.488793996350648e-25},
#  'DM_arach_e': {'KO_flux': 1.0339757656912637e-25, 'init_flux': 0.0},
#  'DM_guln_r': {'KO_flux': 0.5261371138039976, 'init_flux': 0.5261371150551863},
#  'DM_pro__D_x': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_pro__D_e': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_pro__D_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_arg__D_x': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_pro__D_l': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_cmpntm2amep_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_tdchola_x': {'KO_flux': -1.862645149230957e-09, 'init_flux': 0.0},
#  'DM_hretn_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_nrvnccoa_c': {'KO_flux': -5.514537417020184e-25,
#   'init_flux': 3.6784354204405345e-19},
#  'DM_dgdp_n': {'KO_flux': 0.3045751180034131,
#   'init_flux': 0.31888744281604886},
#  'DM_dgdp_m': {'KO_flux': 0.2992005601990968, 'init_flux': 0.318887441229177},
#  'DM_dgdp_c': {'KO_flux': 0.3045751228928566, 'init_flux': 0.3188874336332628},
#  'DM_tdchola_e': {'KO_flux': -1.1292286217212677e-08, 'init_flux': 0.0},
#  'DM_hretn_n': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_tdchola_c': {'KO_flux': -1.862645149230957e-09, 'init_flux': 0.0},
#  'DM_arg__L_m': {'KO_flux': 6.904394831508398e-05,
#   'init_flux': 0.010069043948315084},
#  'DM_Ser_Gly_Ala_X_Gly_r': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_arg__L_c': {'KO_flux': 6.904394831508398e-05,
#   'init_flux': 0.010069043948315084},
#  'DM_arg__L_e': {'KO_flux': 6.904406473040581e-05, 'init_flux': 0.0068},
#  'DM_hmgcoa_r': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_hmgcoa_m': {'KO_flux': 0.3075320387724787,
#   'init_flux': 0.30753204347858804},
#  'DM_cbasp_c': {'KO_flux': 0.6794644533631768,
#   'init_flux': 0.9141290782820015},
#  'DM_adrn_e': {'KO_flux': 7.761021450398115e-11,
#   'init_flux': 1.2755880837423754e-26},
#  'DM_adrn_c': {'KO_flux': 0.0, 'init_flux': -1.826965079152701e-25},
#  'DM_dd3coa_m': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_estradiolglc_e': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_Ser_Gly_Ala_X_Gly_l': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_gm2_hs_g': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_ak2g_hs_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_estradiolglc_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_acald_r': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_itaccoa_m': {'KO_flux': 1.463866699913973e-20, 'init_flux': 0.0},
#  'DM_acald_x': {'KO_flux': 1.080274270246884, 'init_flux': 1.0934181546754116},
#  'DM_acald_c': {'KO_flux': 1.0802742705527009,
#   'init_flux': 1.0934181292685725},
#  'DM_acald_e': {'KO_flux': 1.0802742685191333,
#   'init_flux': 1.0934181748889387},
#  'DM_aprut_c': {'KO_flux': 0.3956266768509522,
#   'init_flux': 0.43171054127742536},
#  'DM_acald_m': {'KO_flux': 1.080274277832359, 'init_flux': 1.0934181248087094},
#  'DM_dolglcp_U_r': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_ggdp_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_mi13456p_c': {'KO_flux': 0.41564290749374777,
#   'init_flux': 0.4156429072609171},
#  'DM_dolglcp_U_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_gpi_prot_hs_r': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_sbt__D_c': {'KO_flux': 0.48181247515133574,
#   'init_flux': 0.4818124695836244},
#  'DM_s2l2n2m2mn_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_thcholoylcoa_x': {'KO_flux': 0.05672273473050417,
#   'init_flux': 0.05743184553678183},
#  'DM_g1m8mpdol__L_r': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_dd2coa_m': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_paf_hs_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_dcsptn1coa_x': {'KO_flux': 0.0, 'init_flux': -4.5615448332722405e-11},
#  'DM_dcyt_c': {'KO_flux': 0.33039117014655484,
#   'init_flux': 0.3371040803613141},
#  'DM_dcyt_e': {'KO_flux': 0.33039116340908387,
#   'init_flux': 0.3371040763714435},
#  'DM_cdpdag_hs_c': {'KO_flux': 0.05217275000177324,
#   'init_flux': 0.05219035898335278},
#  'DM_cdpdag_hs_m': {'KO_flux': 0.05217275000177324,
#   'init_flux': 0.05219035803265187},
#  'DM_ddsmsterol_r': {'KO_flux': 0.06544110154209193,
#   'init_flux': 0.06657156192390239},
#  'DM_dcyt_l': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_dcyt_m': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_ksi_pre18_g': {'KO_flux': 0.0, 'init_flux': -3.9768298680434025e-28},
#  'DM_cys__L_m': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_ecgon_r': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_ura_e': {'KO_flux': 0.8326931762815666, 'init_flux': 0.8326931912451982},
#  'DM_dcsptn1coa_m': {'KO_flux': 0.0, 'init_flux': 1.3403389555251282e-26},
#  'DM_cys__L_e': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_dcsptn1coa_c': {'KO_flux': -3.1313184782663166e-19,
#   'init_flux': -2.0741220134456374e-11},
#  'DM_hnifedipine_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_cys__L_c': {'KO_flux': 0.0, 'init_flux': -7.450580596923828e-09},
#  'DM_glc1man_g': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_amet_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_gluside_hs_l': {'KO_flux': 1.9983994459238304e-09, 'init_flux': 0.0},
#  'DM_ksi_pre14_g': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_amet_m': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_1pipdn2c_x': {'KO_flux': 0.0013169089797884224,
#   'init_flux': 0.001316908979788423},
#  'DM_amet_r': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_acngalacglcgalgluside_hs_g': {'KO_flux': 9.49239667891355e-20,
#   'init_flux': 1.734723475976807e-18},
#  'DM_itp_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_itp_m': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_itp_n': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_ksi_pre16_g': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_appnn_e': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_fucacgalfucgalacglcgalgluside_hs_e': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_galfucgalacglcgalgluside_hs_g': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_fucacgalfucgalacglcgalgluside_hs_g': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_k_c': {'KO_flux': 1.0, 'init_flux': 1.0},
#  'DM_k_e': {'KO_flux': 1.0, 'init_flux': 1.0000000000227243},
#  'DM_fucacgalfucgalacglcgalgluside_hs_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_k_g': {'KO_flux': 1.0, 'init_flux': 0.9999999999999999},
#  'DM_tolbutamide_e': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_ksi_deg21_l': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_thcrm_hs_g': {'KO_flux': 3.446585885727193e-27, 'init_flux': 0.0},
#  'DM_dedolp__L_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_hs_pre4_g': {'KO_flux': 0.0, 'init_flux': -5.610376955514915e-12},
#  'DM_ksi_deg27_l': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_i_e': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_i_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_dhcholestanate_m': {'KO_flux': 0.062466180583608186,
#   'init_flux': 0.06249153537863225},
#  'DM_pcrn_x': {'KO_flux': 0.0, 'init_flux': -2.623234812957519e-25},
#  'DM_fucfuc132galacglcgal14acglcgalgluside_hs_e': {'KO_flux': 0.0,
#   'init_flux': 0.0},
#  'DM_gp1calpha_hs_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_fucfuc132galacglcgal14acglcgalgluside_hs_g': {'KO_flux': 0.0,
#   'init_flux': 0.0},
#  'DM_gp1calpha_hs_e': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_gp1calpha_hs_g': {'KO_flux': 3.5239233753259214e-10, 'init_flux': 0.0},
#  'DM_fucfuc132galacglcgal14acglcgalgluside_hs_c': {'KO_flux': 0.0,
#   'init_flux': 0.0},
#  'DM_cgly_e': {'KO_flux': 0.0, 'init_flux': 3.669029366038427e-12},
#  'DM_ksi_deg23_l': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_dhcholestanate_x': {'KO_flux': 0.062466180583608186,
#   'init_flux': 0.06249153537863225},
#  'DM_pcrn_m': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_r1p_c': {'KO_flux': 0.6009295064689314, 'init_flux': 0.6009295046096668},
#  'DM_pcrn_c': {'KO_flux': 0.0, 'init_flux': 4.6427590668710184e-17},
#  'DM_dhcholestanate_r': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_34hpp_m': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_nadp_r': {'KO_flux': 0.0005947095341980457,
#   'init_flux': 0.0005947102326899767},
#  'DM_34hpp_c': {'KO_flux': 0.005120353191159666,
#   'init_flux': 0.005120353191159666},
#  'DM_udpglcur_c': {'KO_flux': 0.21838221400976246,
#   'init_flux': 0.21838222781361824},
#  'DM_7dhf_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_5a2opntn_x': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_7dhf_e': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_nrpphrsf_e': {'KO_flux': -1.4383732815983906e-08,
#   'init_flux': -3.551497823627886e-10},
#  'DM_dlnlcg_e': {'KO_flux': 0.0, 'init_flux': 2.836047814467521e-24},
#  'DM_dlnlcg_c': {'KO_flux': 0.0, 'init_flux': 2.2058149657167168e-24},
#  'DM_nrpphrsf_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_7dhf_l': {'KO_flux': 1.1641532182693481e-10, 'init_flux': 0.0},
#  'DM_crn_r': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_sgalside_hs_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_Rtotalcoa_c': {'KO_flux': 0.1259523955317055,
#   'init_flux': 0.12599490780000974},
#  'DM_lys__L_m': {'KO_flux': 0.0013169089797884226,
#   'init_flux': 0.0013169089797884226},
#  'DM_sgalside_hs_g': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_cortsn_r': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_crn_x': {'KO_flux': 0.0, 'init_flux': 4.653832563818357e-11},
#  'DM_lys__L_c': {'KO_flux': 0.0013169089797884226,
#   'init_flux': 0.0013169089797884226},
#  'DM_sgalside_hs_l': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_lys__L_x': {'KO_flux': 0.0013169089797884226,
#   'init_flux': 0.0013169089797884226},
#  'DM_crn_c': {'KO_flux': 0.0, 'init_flux': -1.0842352597100094e-19},
#  'DM_3hanthrn_c': {'KO_flux': 0.0005947081372141838,
#   'init_flux': 0.0005947081372141838},
#  'DM_crn_e': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_Rtotalcoa_x': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_crn_m': {'KO_flux': 0.0, 'init_flux': -1.1641532182693481e-09},
#  'DM_10fthf6glu_m': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_10fthf6glu_l': {'KO_flux': 0.0, 'init_flux': -1.1641532184664862e-10},
#  'DM_2hyoxplac_c': {'KO_flux': 0.0009778488893061876,
#   'init_flux': 0.0009778488893061876},
#  'DM_gam6p_c': {'KO_flux': 0.491758855475512, 'init_flux': 0.4977049143053591},
#  'DM_10fthf6glu_e': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_retinal_cis_9_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_ddca_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_ksi_deg12_l': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_10fthf6glu_c': {'KO_flux': 0.0, 'init_flux': -1.4294760573450703e-10},
#  'DM_acgal1p_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_man1p_c': {'KO_flux': 0.5030689093921414,
#   'init_flux': 0.5091898267591336},
#  'DM_L2aadp_c': {'KO_flux': 0.0013169089797884226,
#   'init_flux': 0.0013169089797884226},
#  'DM_ocdca_e': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_hpyr_c': {'KO_flux': 1.1068322038549065, 'init_flux': 1.1068322128600085},
#  'DM_ocdca_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_hpyr_m': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_3mlda_e': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_3mlda_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_4pyrdx_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_hpyr_x': {'KO_flux': 1.1068322038549065, 'init_flux': 1.1068322128600085},
#  'DM_cholcoads_x': {'KO_flux': 0.05720920792463762,
#   'init_flux': 0.05792439902345327},
#  'DM_4pyrdx_e': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_L2aadp_m': {'KO_flux': 0.0013169089797884226,
#   'init_flux': 0.0013169089797884226},
#  'DM_q10h2_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_dkmpp_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_q10h2_m': {'KO_flux': -1.2810641436544756e-10, 'init_flux': 0.0},
#  'DM_acg5p_m': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_5thf_m': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_5thf_l': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_seasmet_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_frdp_r': {'KO_flux': 0.13666066550649725,
#   'init_flux': 0.13666066620387957},
#  'DM_5thf_e': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_seasmet_n': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_ksi_deg18_l': {'KO_flux': 1.7335249946667977e-25, 'init_flux': 0.0},
#  'DM_asp__D_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_6htststerone_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_5thf_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_o2_e': {'KO_flux': 999.9902513747802, 'init_flux': 999.9902513707057},
#  'DM_acac_x': {'KO_flux': 0.7027787417345865, 'init_flux': 0.8311202751574012},
#  'DM_ahandrostanglc_e': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_acetone_c': {'KO_flux': 0.7027787402039394,
#   'init_flux': 0.8311202818198298},
#  'DM_zymst_r': {'KO_flux': 0.06578882140091825,
#   'init_flux': 0.06718230958751646},
#  'DM_o2_c': {'KO_flux': 999.9902513729176, 'init_flux': 999.9902513705892},
#  'DM_im4act_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_o2_m': {'KO_flux': 999.9902513709385, 'init_flux': 999.9902513809502},
#  'DM_im4act_m': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_o2_n': {'KO_flux': 999.9902513711713, 'init_flux': 999.9902513709385},
#  'DM_ksi_deg31_l': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_25hvitd3_e': {'KO_flux': 0.06475657028321381,
#   'init_flux': 0.06617742786088367},
#  'DM_ahandrostanglc_r': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_25hvitd3_c': {'KO_flux': 0.06475657107681383,
#   'init_flux': 0.06617742601445005},
#  'DM_o2_r': {'KO_flux': 999.99025137024, 'init_flux': 999.9902513707057},
# ...
#  'DM_phyt_x': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_phyt_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_hdcecrn_c': {'KO_flux': 0.0, 'init_flux': -5.960377729627582e-10},
#  'DM_phyt_e': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_hdcecrn_m': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_gal14acglcgalgluside_hs_g': {'KO_flux': -1.746229827404022e-09,
#   'init_flux': 1.9402553637822462e-10},
#  'DM_creat_e': {'KO_flux': 6.904394831508398e-05,
#   'init_flux': 0.005069043836556375},
#  'DM_creat_c': {'KO_flux': 6.904394831508398e-05,
#   'init_flux': 0.005069043943658471},
#  'DM_creat_m': {'KO_flux': 6.904406473040581e-05,
#   'init_flux': 0.005069043952971697},
#  'DM_gdpfuc_g': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_dhcholestancoa_x': {'KO_flux': 0.05720920664524628,
#   'init_flux': 0.05792439979271826},
#  'DM_gdpfuc_c': {'KO_flux': 0.19121821282897145,
#   'init_flux': 0.19121821457520127},
#  'DM_42A3HP24DB_c': {'KO_flux': 0.0005947081372141838,
#   'init_flux': 0.0005947081372141838},
#  'DM_g3m8mpdol__L_r': {'KO_flux': 2.8888949165808538e-34, 'init_flux': 0.0},
#  'DM_hcoumarin_e': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_pmtcoa_x': {'KO_flux': 0.12595239471332997,
#   'init_flux': 0.1275289977202192},
#  'DM_leuktrA4_r': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_ksi_deg6_l': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_etha_c': {'KO_flux': 1.0850695456669386, 'init_flux': 1.0850695431772348},
#  'DM_pmtcoa_m': {'KO_flux': 0.125952394126216,
#   'init_flux': 0.1259949109604796},
#  'DM_pmtcoa_c': {'KO_flux': 0.1259523924672976,
#   'init_flux': 0.12599490652792156},
#  'DM_galacglcgalacglcgal14acglcgalgluside_hs_g': {'KO_flux': 0.0,
#   'init_flux': 0.0},
#  'DM_34hpl_m': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_cholcoas_x': {'KO_flux': 0.05770409750402905,
#   'init_flux': 0.05842547620145174},
#  'DM_dcmp_n': {'KO_flux': 0.330391165567562, 'init_flux': 0.33710407538670834},
#  'DM_cholcoas_r': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_uacgam_g': {'KO_flux': -1.1641532182693481e-10,
#   'init_flux': 1.9407671523285565e-11},
#  'DM_Lpipecol_x': {'KO_flux': 0.0013169089797884226,
#   'init_flux': 0.0013169089797884222},
#  'DM_uacgam_c': {'KO_flux': 0.1803191176149994,
#   'init_flux': 0.18031912491209748},
#  'DM_ksi_deg4_l': {'KO_flux': 2.592220933704908e-25, 'init_flux': 0.0},
#  'DM_dgtp_n': {'KO_flux': 0.29920026543550193,
#   'init_flux': 0.3129454277339122},
#  'DM_dgtp_m': {'KO_flux': 0.2940121129391249, 'init_flux': 0.312945440877229},
#  'DM_ppmi1346p_n': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_dgtp_c': {'KO_flux': 0.29920025882881524,
#   'init_flux': 0.3129454391342671},
#  'DM_lnlncacoa_c': {'KO_flux': -9.584791224821209e-27,
#   'init_flux': 2.2118911062995868e-10},
#  'DM_3moxtyr_c': {'KO_flux': 0.0051203531911596665,
#   'init_flux': 0.005120353191159666},
#  'DM_56dihindlcrbxlt_c': {'KO_flux': 0.005120353191159666,
#   'init_flux': 0.005120353191159666},
#  'DM_xan_c': {'KO_flux': 0.6794644398149144, 'init_flux': 0.6794644635518917},
#  'DM_estrone_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_hdd2coa_c': {'KO_flux': 0.1259523924479658,
#   'init_flux': 0.1259949053713385},
#  'DM_val__L_c': {'KO_flux': 0.0010756943374872208,
#   'init_flux': 0.0010756943374872208},
#  'DM_pyr_c': {'KO_flux': 1.10683221314139, 'init_flux': 1.3087651270907372},
#  'DM_estrone_r': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_amet_n': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_lneldc_e': {'KO_flux': 0.11426609005852177,
#   'init_flux': 0.1142660942138146},
#  'DM_cs_b_l': {'KO_flux': -4.265358692840527e-11, 'init_flux': 0.0},
#  'DM_ksi_deg1_e': {'KO_flux': 0.0, 'init_flux': 1.1488619618792009e-26},
#  'DM_whtststerone_e': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_abt_c': {'KO_flux': 0.5261371024218711, 'init_flux': 0.5325389009533814},
#  'DM_coumarin_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_abt_e': {'KO_flux': 0.526137113571167, 'init_flux': 0.5325389024320453},
#  'DM_whtststerone_r': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_cs_d_l': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_pmtcrn_m': {'KO_flux': -1.2102344123278565e-08,
#   'init_flux': -1.6007258170879052e-10},
#  'DM_dmhptcoa_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_mpdol_U_c': {'KO_flux': 7.202200145796566e-21, 'init_flux': 0.0},
#  'DM_dmhptcoa_m': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_fe3_e': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_lgnccoa_c': {'KO_flux': 1.6530757851487078e-25,
#   'init_flux': 1.2485692743497955e-10},
#  'DM_xol25oh_r': {'KO_flux': 0.06441964825614876,
#   'init_flux': 0.0648041716223411},
#  'DM_appnn_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_tettet6_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_tettet6_e': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_hs_deg10_l': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_2dp6mobq_m': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_ksi_deg9_l': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_dutp_c': {'KO_flux': 0.3241179179167375, 'init_flux': 0.3305157202089005},
#  'DM_ksi_deg36_l': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_gly_x': {'KO_flux': 1.10683220448524, 'init_flux': 2.070532720703258},
#  'DM_hs_deg14_l': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_ksi_deg38_l': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_nmthsrtn_c': {'KO_flux': 0.0005947081372141838,
#   'init_flux': 0.0005947081372141838},
#  'DM_glyald_c': {'KO_flux': 0.9773634586545746,
#   'init_flux': 0.9773634861166771},
#  'DM_retinol_9_cis_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_44mctr_r': {'KO_flux': 0.06685451557443116,
#   'init_flux': 0.06905216022879855},
#  'DM_ksii_core4_pre3_g': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_pyr_x': {'KO_flux': 1.106832207296975, 'init_flux': 1.308765135737809},
#  'DM_agm_m': {'KO_flux': 6.904394831508398e-05,
#   'init_flux': 0.010069043948315084},
#  'DM_3uib_c': {'KO_flux': 0.5335243564885059, 'init_flux': 0.5545192336410452},
#  'DM_mi4p__D_c': {'KO_flux': 0.4493436828480682,
#   'init_flux': 0.449343687698434},
#  'DM_ahcys_r': {'KO_flux': 1.734723475976807e-18, 'init_flux': 0.0},
#  'DM_arachcrn_c': {'KO_flux': -8.618954266244262e-20,
#   'init_flux': 2.85753302518319e-25},
#  'DM_hs_pre7_g': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_arachcrn_m': {'KO_flux': -8.618954266244262e-20, 'init_flux': 0.0},
#  'DM_fe2_c': {'KO_flux': 1000.0, 'init_flux': 1000.0},
#  'DM_ahcys_c': {'KO_flux': 1.734723475976807e-18, 'init_flux': 0.0},
#  'DM_4aabutn_m': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_fe2_e': {'KO_flux': 1000.0, 'init_flux': 1000.0},
#  'DM_galgalfucfucgalacglcgalacglcgal14acglcgalgluside_hs_c': {'KO_flux': 0.0,
#   'init_flux': 0.0},
#  'DM_galgalfucfucgalacglcgalacglcgal14acglcgalgluside_hs_g': {'KO_flux': 0.0,
#   'init_flux': 0.0},
#  'DM_4aabutn_c': {'KO_flux': 0.4084716980127523,
#   'init_flux': 0.40847170096822083},
#  'DM_galgalfucfucgalacglcgalacglcgal14acglcgalgluside_hs_e': {'KO_flux': 0.0,
#   'init_flux': 0.0},
#  'DM_ahcys_n': {'KO_flux': 1.734723475976807e-18, 'init_flux': 0.0},
#  'DM_hs_pre3_g': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_acgbgbside_hs_g': {'KO_flux': 2.9103830456733704e-11,
#   'init_flux': -3.8805107275644935e-10},
#  'DM_ahdt_c': {'KO_flux': 0.32815513196547397,
#   'init_flux': 0.3281551251420751},
#  'DM_ksii_core2_pre10_g': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_acgbgbside_hs_c': {'KO_flux': 2.9103830456733704e-11,
#   'init_flux': -3.8805107275644935e-10},
#  'DM_acgbgbside_hs_l': {'KO_flux': 2.9103830456733704e-11,
#   'init_flux': -7.761021455128987e-11},
#  'DM_ahdt_n': {'KO_flux': 0.32815512103095323,
#   'init_flux': 0.3281551265989022},
#  'DM_1mpyr_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_prostgh2_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_hs_pre5_g': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_cs_b_deg1_l': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_prostgh2_r': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_m_em_3gacpail_prot_hs_r': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_decdp_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_decdp_m': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_cs_b_deg3_l': {'KO_flux': 0.0, 'init_flux': -1.566548270712558e-10},
#  'DM_pglyc_hs_c': {'KO_flux': 0.05674305891863187,
#   'init_flux': 0.05676221057422345},
#  'DM_sel_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_dtdp4d6dm_c': {'KO_flux': 0.18034626122222025,
#   'init_flux': 0.18034626462296421},
#  'DM_sel_e': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_nm4masn_g': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_sTn_antigen_g': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_cmusa_c': {'KO_flux': 0.0005947081372141838,
#   'init_flux': 0.0005947081372141838},
#  'DM_strch1_e': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_ribflv_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_paps_g': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_whttdca_e': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_whttdca_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_ribflv_e': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_m4mpdol_U_r': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_fna5moxam_c': {'KO_flux': 0.0005947081732519838,
#   'init_flux': 0.0005947081372141838},
#  'DM_trdox_m': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_malcoa_x': {'KO_flux': -2.363373178722936e-25, 'init_flux': 0.0},
#  'DM_trdox_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_m4mpdol_U_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_dmnoncoa_x': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_xoltri27_c': {'KO_flux': 0.06408621405716985,
#   'init_flux': 0.06408621312584728},
#  'DM_3ohdcoa_x': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_ksii_core4_pre5_g': {'KO_flux': 1.3463226115771936e-28, 'init_flux': 0.0},
#  'DM_andrstrnglc_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_ebastineoh_r': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_andrstrnglc_e': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_ksii_core4_pre7_g': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_xoltri27_r': {'KO_flux': 0.06408621290020694,
#   'init_flux': 0.06408621021546423},
#  'DM_dmnoncoa_m': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_gt2_hs_g': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_arachdcrn_c': {'KO_flux': -8.979470735448029e-40,
#   'init_flux': 2.735545926009451e-19},
#  'DM_andrstrnglc_r': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_ak2gp_hs_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_ebastineoh_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_ebastineoh_e': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_spmd_c': {'KO_flux': 0.2813830171380572,
#   'init_flux': 0.28138301085250883},
#  'DM_digalsgalside_hs_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_acgalfucgalacglcgalgluside_hs_g': {'KO_flux': 0.0,
#   'init_flux': -1.579922224794115e-10},
#  'DM_digalsgalside_hs_e': {'KO_flux': -3.725290298461914e-09,
#   'init_flux': 0.0},
#  'DM_digalsgalside_hs_g': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_glc__D_c': {'KO_flux': 0.5174277119436861,
#   'init_flux': 0.5175927754539085},
#  'DM_glc__D_l': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_npthl_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_mi14p_c': {'KO_flux': 0.4493436834681569,
#   'init_flux': 0.4493436846431794},
#  'DM_npthl_e': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_hs_pre8_g': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_23doguln_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_dak2gpe_hs_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_yvite_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_yvite_e': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_glc__D_r': {'KO_flux': 0.5174277268344023,
#   'init_flux': 0.5175927749214077},
#  'DM_sphs1p_c': {'KO_flux': 0.11739222041796893,
#   'init_flux': 0.11739222146570683},
#  'DM_strdnccrn_m': {'KO_flux': -1.4147435452622685e-19, 'init_flux': 0.0},
#  'DM_2dpmhobq_m': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_34dhcinm_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_l2fn2m2masn_g': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_cs_e_deg5_l': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_ksi_pre1_g': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_5aizc_c': {'KO_flux': 0.36326385096631136,
#   'init_flux': 0.37643330497667193},
#  'DM_gar_c': {'KO_flux': 0.4081131847342476, 'init_flux': 0.40811319296252313},
#  'DM_gcald_c': {'KO_flux': 1.1068322020582855,
#   'init_flux': 1.1068322084611282},
#  'DM_gcald_m': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_ksi_pre3_g': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_3hpcoa_m': {'KO_flux': 0.4047789840472177,
#   'init_flux': 0.40477898104156723},
#  'DM_cs_e_deg1_l': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_pail5p_hs_c': {'KO_flux': 0.05406736967519724,
#   'init_flux': 0.05406737051374151},
#  'DM_pail5p_hs_n': {'KO_flux': 0.05406736861914396,
#   'init_flux': 0.054067370364609166},
#  'DM_co2_r': {'KO_flux': 3.3973222468048334, 'init_flux': 5.397322257980704},
#  'DM_4nph_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_akg_m': {'KO_flux': 0.6728441151790321, 'init_flux': 0.7720156585279911},
#  'DM_akg_r': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_tsul_m': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_3hpcoa_x': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_pail5p_hs_r': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_uppg3_c': {'KO_flux': 0.06917701339989438,
#   'init_flux': 0.06917701460788023},
#  'DM_tsul_e': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_co2_c': {'KO_flux': 3.3973222818458453, 'init_flux': 5.4423222676850855},
#  'DM_co2_e': {'KO_flux': 3.397322278966628, 'init_flux': 5.397322356700897},
#  'DM_co2_g': {'KO_flux': 3.3973222468048334, 'init_flux': 5.397322259377688},
#  'DM_tsul_c': {'KO_flux': 2.3283064365386963e-10, 'init_flux': 0.0},
#  'DM_mthgxl_c': {'KO_flux': 0.9779833126843804,
#   'init_flux': 0.9902251663015169},
#  'DM_cs_e_deg3_l': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_eryth_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_mthgxl_e': {'KO_flux': 0.9779833022039384,
#   'init_flux': 0.977983315025525},
#  'DM_acgagbside_hs_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_acgagbside_hs_g': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_ocdcea_e': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_acgagbside_hs_l': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_ocdcea_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_ksii_core4_pre8_g': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_mercppyr_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_mercppyr_m': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_em3gacpail_hs_r': {'KO_flux': 0.028468691328111126,
#   'init_flux': 0.028468692442402063},
#  'DM_15HPET_c': {'KO_flux': 0.0, 'init_flux': -2.891718405728733e-12},
#  'DM_6dhf_l': {'KO_flux': 0.0, 'init_flux': 1.1641532182693481e-10},
#  'DM_6dhf_m': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_12ppd__R_c': {'KO_flux': 0.7557143774614388,
#   'init_flux': 0.7651739652307468},
#  'DM_hcys__L_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_6dhf_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_6dhf_e': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_imp_e': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_hs_deg8_l': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_imp_c': {'KO_flux': 0.32815512659726664, 'init_flux': 0.3485737569841201},
#  'DM_c2m26dcoa_m': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_dlnlcgcoa_c': {'KO_flux': 2.9103830427411863e-11,
#   'init_flux': -1.2666581544817947e-14},
#  'DM_dlnlcgcoa_m': {'KO_flux': 0.0, 'init_flux': -1.3175052662976144e-10},
#  'DM_imp_m': {'KO_flux': 0.3219243323010942, 'init_flux': 0.32192433907457635},
#  'DM_cs_c_pre2_g': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_odecoa_x': {'KO_flux': 0.11010408094076964,
#   'init_flux': 0.11010408106982898},
#  'DM_c2m26dcoa_x': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_mi1346p_n': {'KO_flux': 0.4156429113354534,
#   'init_flux': 0.41564291215036064},
#  'DM_odecoa_c': {'KO_flux': 0.11010408094076964,
#   'init_flux': 0.1101412435657814},
#  'DM_eicostetcrn_m': {'KO_flux': 0.0, 'init_flux': -2.515634717330671e-18},
#  'DM_odecoa_m': {'KO_flux': 0.11010408096952051,
#   'init_flux': 0.11014124353672834},
#  'DM_ksi_pre4_g': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_vacccoa_c': {'KO_flux': 0.11010408010343894,
#   'init_flux': 0.11014124556765065},
#  'DM_pppg9_m': {'KO_flux': 0.0691770119717524, 'init_flux': 0.069177013657456},
#  'DM_malACP_c': {'KO_flux': 0.0, 'init_flux': 0.0},
#  'DM_cbp_r': {'KO_flux': 3.3973221556516364, 'init_flux': 5.397322270825486},
#  'DM_pppg9_c': {'KO_flux': 0.06917701265774667,
#   'init_flux': 0.08079624373931438},
#  'DM_Ssq23epx_r': {'KO_flux': 0.06758436838182375,
#   'init_flux': 0.06758436938333842},
#  'DM_34dhphe_e': {'KO_flux': 0.005120353191159666,
#   'init_flux': 0.005120353191159666},
#  'DM_34dhphe_c': {'KO_flux': 0.0051203536787680776,
#   'init_flux': 0.005120353191159666},
#  ...}

# %%
# Setting the cutoff to 10^-5

for rxn, flux in combined_dic.iteritems():
    # 10^-5
    if round(flux['init_flux'], 6) < 0.00001:
        flux['init_flux'] = 0
    if round(flux['KO_flux'], 6) < 0.00001:
        flux['KO_flux'] = 0

# %%
G1 = {}
G2 = {}
G3 = {}

for rxn, flux in combined_dic.iteritems():
    # if both init and final are 0, stored into group 1
    if flux['init_flux'] == 0 and flux['KO_flux'] == 0:
        G1[rxn] = {'init_flux': flux['init_flux'], 'KO_flux': flux['KO_flux']}
        
    # if both init and final are non-zero, stored into group 1
    if flux['init_flux'] != 0 and flux['KO_flux'] != 0:
        G1[rxn] = {'init_flux': flux['init_flux'], 'KO_flux': flux['KO_flux']}
        
    # if init is 0 and final is non-zero, stored into group 2
    if flux['init_flux'] == 0 and flux['KO_flux'] != 0:
        G2[rxn] = {'init_flux': flux['init_flux'], 'KO_flux': flux['KO_flux']}
        
    # if init is non-zero and final is 0, stored into group 3
    if flux['init_flux'] != 0 and flux['KO_flux'] == 0:
        G3[rxn] = {'init_flux': flux['init_flux'], 'KO_flux': flux['KO_flux']}

# %% [markdown]
# ### G1

# %%
# Execute divisions using this function
# This catches divisions of denominator 0 and just outputs 0
def safe_div(x,y):
    if y == 0:
        return 0
    return x / y

# %%
# This is the first step of normalization
# This is the flux of KO - initial flux
G1_output_norm_dic = {a: {'init_flux': b['init_flux'], 'KO_flux': b['KO_flux'], 'normalized_flux':
                       safe_div((b['KO_flux']-b['init_flux']),b['init_flux']), 
                          'absolute_normalized_flux': abs(safe_div((b['KO_flux']-b['init_flux']),b['init_flux']))} for a,b in G1.iteritems()}

# %%
# Ranks based on criteria by creating an ordered dictionary
# G1 -- normalized flux ranking (ratio)
import operator
import collections


G1_descending = collections.OrderedDict(sorted(G1_output_norm_dic.items(),
                                               key=lambda kv: kv[1]['absolute_normalized_flux'], reverse=True))

# %%
# writing KO_maxmet_dict as a .csv file

metabolite_demand_dic = [0] * len(G1_descending)
init_flux_out_dic = [0] * len(G1_descending)
KO_flux_out_dic = [0] * len(G1_descending)
normalized_flux_out_dic = [0] * len(G1_descending)
absolute_normalized_flux_out_dic = [0] * len(G1_descending)

metabolite_demand_count = 0
init_flux_count = 0
KO_flux_count = 0
normalized_flux_count = 0
absolute_normalized_flux_count = 0

for key, value in G1_descending.iteritems():
    metabolite_demand_dic[metabolite_demand_count] = key
    metabolite_demand_count = metabolite_demand_count + 1
    
for a, b in G1_descending.iteritems():
    init_flux_out_dic[init_flux_count] = b['init_flux']
    init_flux_count = init_flux_count + 1
    
for c, d in G1_descending.iteritems():
    KO_flux_out_dic[KO_flux_count] = d['KO_flux']
    KO_flux_count = KO_flux_count + 1
    

for e, f in G1_descending.iteritems():
    normalized_flux_out_dic[normalized_flux_count] = f['normalized_flux']
    normalized_flux_count = normalized_flux_count + 1  
    
for g, h in G1_descending.iteritems():
    absolute_normalized_flux_out_dic[absolute_normalized_flux_count] = h['absolute_normalized_flux']
    absolute_normalized_flux_count = absolute_normalized_flux_count + 1  
    
# this saves the array into a .csv file as named

import csv
from itertools import izip

with open(str(gene_name)+'_withProduct_G1_ranked_fluxes.csv', 'wb') as f:
    writer = csv.writer(f)
    writer.writerow(['metabolite_demand', 'init_flux', 'KO_flux', 'normalized_flux', 'absolute_normalized_flux'])
    writer.writerows(izip(metabolite_demand_dic, init_flux_out_dic, KO_flux_out_dic, normalized_flux_out_dic, absolute_normalized_flux_out_dic))

# %% [markdown]
# ### G2

# %%
# Ranks based on criteria by creating an ordered dictionary
# G2 -- ranked based on final KO flux value

G2_descending = collections.OrderedDict(sorted(G2.items(),key=lambda kv: kv[1]['KO_flux'], reverse=True))

# %%
G2_descending
# Out:
# OrderedDict()

# %%
# writing ARGSSKO_maxmet_dict as a .csv file

metabolite_demand_dic = [0] * len(G2_descending)
init_flux_out_dic = [0] * len(G2_descending)
KO_flux_out_dic = [0] * len(G2_descending)


metabolite_demand_count = 0
init_flux_count = 0
KO_flux_count = 0


for key, value in G2_descending.iteritems():
    metabolite_demand_dic[metabolite_demand_count] = key
    metabolite_demand_count = metabolite_demand_count + 1
    
for a, b in G2_descending.iteritems():
    init_flux_out_dic[init_flux_count] = b['init_flux']
    init_flux_count = init_flux_count + 1
    
for c, d in G2_descending.iteritems():
    KO_flux_out_dic[KO_flux_count] = d['KO_flux']
    KO_flux_count = KO_flux_count + 1

# %%
# this saves the array into a .csv file as named

import csv
from itertools import izip

with open(str(gene_name)+'_withProduct_G2_ranked_fluxes.csv', 'wb') as f:
    writer = csv.writer(f)
    writer.writerow(['metabolite_demand', 'init_flux', 'KO_flux'])
    writer.writerows(izip(metabolite_demand_dic, init_flux_out_dic, KO_flux_out_dic, normalized_flux_out_dic, absolute_normalized_flux_out_dic))

# %% [markdown]
# ### G3

# %%
# Ranks based on criteria by creating an ordered dictionary
# G3 -- ranked based on initial flux value

G3_descending = collections.OrderedDict(sorted(G3.items(),key=lambda kv: kv[1]['init_flux'], reverse=True))

# %%
# writing ARGSSKO_maxmet_dict as a .csv file

metabolite_demand_dic = [0] * len(G3_descending)
init_flux_out_dic = [0] * len(G3_descending)
KO_flux_out_dic = [0] * len(G3_descending)


metabolite_demand_count = 0
init_flux_count = 0
KO_flux_count = 0


for key, value in G3_descending.iteritems():
    metabolite_demand_dic[metabolite_demand_count] = key
    metabolite_demand_count = metabolite_demand_count + 1
    
for a, b in G3_descending.iteritems():
    init_flux_out_dic[init_flux_count] = b['init_flux']
    init_flux_count = init_flux_count + 1
    
for c, d in G3_descending.iteritems():
    KO_flux_out_dic[KO_flux_count] = d['KO_flux']
    KO_flux_count = KO_flux_count + 1

# %%
# this saves the array into a .csv file as named

import csv
from itertools import izip

with open(str(gene_name)+'_withProduct_G3_ranked_fluxes.csv', 'wb') as f:
    writer = csv.writer(f)
    writer.writerow(['metabolite_demand', 'init_flux', 'KO_flux'])
    writer.writerows(izip(metabolite_demand_dic, init_flux_out_dic, KO_flux_out_dic, normalized_flux_out_dic, absolute_normalized_flux_out_dic))
